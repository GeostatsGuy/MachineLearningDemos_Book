# %% [markdown]
# <figure style="text-align: center;">
#   <img src="_static/intro/title_page.png" style="display: block; margin: 0 auto; width: 100%;">
# </figure>
#
# ### Machine Learning Glossary
#
# Michael J. Pyrcz, Professor, The University of Texas at Austin
#
# [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Geostatistics Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [Applied Geostats in Python e-book](https://geostatsguy.github.io/GeostatsPyDemos_Book/intro.html) | [Applied Machine Learning in Python e-book](https://geostatsguy.github.io/MachineLearningDemos_Book/) | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
#
# Chapter of e-book "Applied Machine Learning in Python: a Hands-on Guide with Code".
#
# ```{admonition} Cite this e-Book as:
# :class: remove-from-content-only
#
# Pyrcz, M.J., 2024, *Applied Machine Learning in Python: A Hands-on Guide with Code* [e-book]. Zenodo. doi:10.5281/zenodo.15169139 [![DOI](https://zenodo.org/badge/863274676.svg)](https://doi.org/10.5281/zenodo.15169139)
# ```
#
# The workflows in this book and more are available here:
#
# ```{admonition} Cite the MachineLearningDemos GitHub Repository as:
# :class: remove-from-content-only
#
# Pyrcz, M.J., 2024, *MachineLearningDemos: Python Machine Learning Demonstration Workflows Repository* (0.0.3) [Software]. Zenodo. DOI: 10.5281/zenodo.13835312. GitHub repository: https://github.com/GeostatsGuy/MachineLearningDemos [![DOI](https://zenodo.org/badge/862519860.svg)](https://zenodo.org/doi/10.5281/zenodo.13835312)
# ```
#
# By Michael J. Pyrcz <br />
# &copy; Copyright 2024.

# %% [markdown]
# This chapter is a summary of essential **Machine Learning Terminology**.
#
# #### Motivation for this Glossary
#
# Firstly, why create this glossary?
#
# I received a request for a course glossary from students in my **Subsurface Machine Learning** graduate course. While I usually dedicate a definition slide in my lecture slide decks to important terms, various students requested a consolidated glossary of terminology as part of their course review materials. The e-book provides an excellent vehicle and motivation for creating this resource.
#
# Let me begin with a confession. There is a [Machine Learning Glossary](https://developers.google.com/machine-learning/glossary) written by Google developers. For those seeking the in depth, comprehensive list of machine learning terms please use this book! For those seeking a comprehensive and in-depth reference of geostatistical terminology, this book remains an excellent resource.
#
# So why create another glossary?
#
# * **Scope** - By writing my own glossary, I can limit the scope and descriptions to the concepts covered in this course. I believe many students would be overwhelmed by the size, breadth, and mathematical notation of a comprehensive geostatistics glossary.
#
# * **Statistical Linkages** - At the same time in my opinion machine learning is statistical learning and I have taken liberty to include many standard statistical terms as a foundation for all things machine learing.
#
# * **Workflow Integration** - By integrating the glossary directly into the e-book, I can link terminology to detailed chapter discussions, demonstrations, and examples. The goal is to eventually populate all chapters with hyperlinks to glossary entries, enabling students to move easily between concepts and applications.
#
# * **Evergreen Resource** - Finally, like the rest of this e-book, I want the glossary to be an **evergreen living document**. It will continue to evolve with new concepts, improved explanations, and feedback from students and readers.
#
# I put quite a bit of time into this project during summer 2026 and I am happy with the way that is has evolved,
#
# * More than a glossary, it has become an evergreen network of machine learning concepts.

# %% [markdown]
# #### **Gaussian Anamorphosis**
#
# A quantile transformation that maps any [univariate](MachineLearning_glossary_s_z.ipynb#univariate) distribution to a Gaussian distribution,
#
# * also known as a normal score transform
#
# The transformation maps feature values through their cumulative probabilities,
#
# $$
# y = G_y^{-1}\left( F_x(x)\right)
# $$
#
# where $F_x$ is the [cumulative distribution function](MachineLearning_glossary_a_c.ipynb#cumulative-distribution-function) of the original feature distribution and $G_y$ is the Gaussian CDF.
#
# The Gaussian [probability density function](MachineLearning_glossary_m_r.ipynb#probability-density-function) is,
#
# $$
# f(x) = \frac{1}{\sigma \sqrt{2 \pi}} exp \left[-\frac{1}{2} \left(\frac{x-\mu}{\sigma} \right)^2 \right]
# $$
#
# A shorthand notation for a normal distribution is,
#
# $$
# N[\mu,\sigma^2]
# $$
#
# for example, $N[0,1]$ is the standard normal distribution.
#
# Properties of Gaussian distributions,
#
# * much of natural variation and measurement error can be approximately represented by Gaussian distributions
#
# * parameterized completely by the mean, variance, and [correlation coefficient](MachineLearning_glossary_a_c.ipynb#correlation-coefficient)s for [multivariate](MachineLearning_glossary_m_r.ipynb#multivariate) Gaussian distributions
#
# * unbounded distribution with no minimum or maximum values; extreme values are increasingly unlikely, and practical applications often apply truncation limits
#
# Warning, many workflows apply univariate Gaussian anamorphosis and then assume a [bivariate](MachineLearning_glossary_a_c.ipynb#bivariate) or multivariate Gaussian distribution. This assumption is generally not correct, but transforming data to a true multivariate Gaussian distribution is often computationally difficult.
#
# Methods that benefit from or require Gaussian distributed features,
#
# * Pearson product-moment correlation coefficients completely characterize multivariate relationships when data follow a multivariate Gaussian distribution
#
# * [partial correlation coefficient](MachineLearning_glossary_m_r.ipynb#partial-correlation-coefficient)s have their strongest statistical interpretation under multivariate normality
#
# * sequential Gaussian simulation (SGS) assumes Gaussian distributions to reproduce spatial variability and the global distribution
#
# * Student's t-test for differences in means assumes normally distributed populations
#
# * chi-square distributions are derived from sums of squares of Gaussian distributed [random variable](MachineLearning_glossary_m_r.ipynb#random-variable)s
#
# * Gaussian [naive Bayes](MachineLearning_glossary_m_r.ipynb#naive-bayes) [classification](MachineLearning_glossary_a_c.ipynb#classification) assumes Gaussian conditional distributions
#
# Used in:
# - [Gaussian Anamorphosis Description and Demonstration](MachineLearning_feature_transformations.ipynb#gaussian-transformation)
#
# Also see:
# - [Distribution Transformation](MachineLearning_glossary_d_f.ipynb#distribution-transformation)
#
# Constrast with:
# - [Affine Correction](MachineLearning_glossary_a_c.ipynb#affine-correction)
#
#
# #### **Generative Adversarial Network**
#
# Machine learning architecture where two [neural network](MachineLearning_glossary_m_r.ipynb#neural-network)s are trained competitively against each other in an adversarial learning process,
#
# * generator - neural network that generates synthetic data attempting to produce samples that the discriminator classifies as real
#
# * discriminator - neural network that classifies samples as real (from the training dataset) or generated (from the generator)
#
# The adversarial training concept is,
#
# * the generator learns to create increasingly realistic synthetic samples
#
# * the discriminator learns to distinguish generated samples from real training samples
#
# * the generator improves based on feedback from the discriminator
#
# The adversarial objective can be expressed as a minimax optimization problem,
#
# $$
# \min_G \max_D V(D,G)=E_{x\sim p_{data}(x)}[\log D(x)]+E_{z\sim p_z(z)}[\log(1-D(G(z)))]
# $$
#
# where $G$ is the generator, $D$ is the discriminator, $x$ represents real training data, and $z$ is random input noise.
#
# Additional points about generative adversarial networks,
#
# * the generator does not directly observe the real training samples; instead, it learns from the discriminator's feedback about generated samples
#
# * the discriminator provides a learned objective function that guides the generator toward realistic data generation
#
# * directly minimizing distance to training samples may cause the model to reproduce existing samples rather than generate diverse new [realization](MachineLearning_glossary_m_r.ipynb#realization)s
#
# * adversarial training encourages the generator to reproduce the statistical characteristics and variability of the training data
#
# Training generative adversarial networks,
#
# * the generator starts with random [weight](MachineLearning_glossary_s_z.ipynb#weight)s and produces random synthetic samples
#
# * the discriminator starts with random weights and initially performs poorly at distinguishing real and generated samples
#
# * generator and discriminator training must remain balanced; a discriminator that becomes too accurate can provide weak learning signals to the generator
#
# * gradients from the discriminator are propagated backward through the network to update generator weights
#
# Applications of generative adversarial networks include,
#
# * image enhancement and super resolution - increasing image resolution and improving visual quality
#
# * synthetic image generation - generating realistic images and scientific models
#
# * geostatistical modeling - generating heterogeneous subsurface realizations that reproduce spatial patterns and geological variability
#
# Variants of generative adversarial networks include,
#
# * conditional generative adversarial network (cGAN) - incorporates labels or conditioning information to control generated outputs
#
# * cycleGAN - learns transformations between two image domains without paired examples
#
# * pix2pix - performs image-to-image translation using paired training examples
#
# Training generative adversarial networks,
#
# * network weights and biases are estimated using backpropagation and [gradient-based optimization](MachineLearning_glossary_g_l.ipynb#gradient-based-optimization)
#
# * gradients pass through the discriminator and provide learning signals to update the generator
#
# * training can be challenging due to unstable optimization and balancing the competing objectives of the two networks
#
# Used in:
# - [Generative Adversarial Network Description and Demonstration](MachineLearning_GAN.ipynb#generative-adversarial-networks-method)
#
# Also see:
# - [Neural Network](MachineLearning_glossary_m_r.ipynb#neural-network)
# - [Activation Function](MachineLearning_glossary_a_c.ipynb#activation-function)
# - [Backpropagation](MachineLearning_glossary_a_c.ipynb#backpropagation)
# - [Convolutional Neural Network](MachineLearning_glossary_a_c.ipynb#convolutional-neural-network)
# - [Recurrent Neural Network](MachineLearning_glossary_m_r.ipynb#recurrent-neural-network)
#
#
# #### **Geostatistics**
#
# A branch of applied statistics that integrates,
#
# 1. spatial (geological) context
#
# 2. spatial relationships and continuity
#
# 3. [volume support](MachineLearning_glossary_s_z.ipynb#volume-support)  and scale
#
# 4. uncertainty
#
# Geostatistics provides methods to characterize, model, predict, and simulate spatial phenomena by incorporating the spatial structure of the data and the uncertainty in the subsurface or other spatial systems to support optimum [decision making](MachineLearning_glossary_d_f.ipynb#decision-making).
#
# The boundary between geostatistics and spatial statistics is debated. In this course,
#
# * geostatistics includes many spatial statistics methods because, in practice, useful approaches for modeling spatial phenomena are adopted and integrated into the geostatistical toolkit.
#
# Geostatistics is an expanding and evolving field of study that continues to incorporate new statistical, computational, and data-driven approaches.
#
#
# #### **Gibbs Sampler**
#
# A [Markov chain Monte Carlo](MachineLearning_glossary_m_r.ipynb#markov-chain-monte-carlo) simulation algorithm that generates samples from a target probability distribution such that, after convergence, the ensemble of samples reproduces the statistics of the target distribution.
#
# The Gibbs sampler is based on,
#
# * sequentially sampling from conditional probability distributions
#
# Since only conditional [probability density function](MachineLearning_glossary_m_r.ipynb#probability-density-function)s are required, the sampling process is simplified because the full [joint probability](MachineLearning_glossary_g_l.ipynb#joint-probability) density function is not directly required.
#
# The basic steps of the Gibbs MCMC sampler for a [bivariate](MachineLearning_glossary_a_c.ipynb#bivariate) case are,
#
# 1. Assign initial random values for $X(0)$, $Y(0)$
#
# 2. Sample from $f(X|Y(0))$ to obtain $X(1)$
#
# 3. Sample from $f(Y|X(1))$ to obtain $Y(1)$
#
# 4. Repeat the sequential conditional sampling steps to generate samples,
#
# $$
# \ell = 1,\ldots,L
# $$
#
# After sufficient iterations and convergence, the resulting samples reproduce the target joint distribution,
#
# $$
# f(X,Y)
# $$
#
# The Gibbs sampler is particularly useful when the joint distribution is complex, but the conditional distributions are easier to sample from.
#
# Used in:
# TBA - with Bayesian Linear Regression
#
# Compare with:
# - [Metropolis-Hastings](MachineLearning_glossary_m_r.ipynb#metropolis-hastings)
#
# Also see:
# - [Markov Chain Monte Carlo](MachineLearning_glossary_m_r.ipynb#markov-chain-monte-carlo)
#
#
# #### **Global Accuracy**
#
# Honoring (matching) [global measures](MachineLearning_glossary_g_l.ipynb#global-measure) calculated over the entire [volume of interest](MachineLearning_glossary_s_z.ipynb#volume-of-interest), for example,
#
# * [average](MachineLearning_glossary_a_c.ipynb#average)
#
# * [variance](MachineLearning_glossary_a_c.ipynb#correlation-coefficient)
#
# * [cumulative distribution function](MachineLearning_glossary_a_c.ipynb#cumulative-distribution-function)
#
# * [variogram](MachineLearning_glossary_s_z.ipynb#variogram)
#
# * [correlation coefficient](MachineLearning_glossary_a_c.ipynb#correlation-coefficient)
#
# Global accuracy is a primary objective for [simulation](MachineLearning_glossary_s_z.ipynb#simulation), where the [realization](MachineLearning_glossary_m_r.ipynb#realization)s should reproduce the input global statistics in [expectation](MachineLearning_glossary_d_f.ipynb#expectation).
#
# Used in:
# - [Model Checks for Global Accuracy](MachineLearning_model_checking.ipynb#spatial-modeling)
#
# Contrast with:
# - [Local Accuracy](MachineLearning_glossary_g_l.ipynb#local-accuracy)
#
#
# #### **Global Measure**
#
# A statistical or spatial summary calculated over the entire [volume of interest](MachineLearning_glossary_s_z.ipynb#volume-of-interest). Examples include,
#
# * [average](MachineLearning_glossary_a_c.ipynb#average)
#
# * [variance](MachineLearning_glossary_a_c.ipynb#correlation-coefficient)
#
# * [cumulative distribution function](MachineLearning_glossary_a_c.ipynb#cumulative-distribution-function)
#
# * [variogram](MachineLearning_glossary_s_z.ipynb#variogram)
#
# * [correlation coefficient](MachineLearning_glossary_a_c.ipynb#correlation-coefficient)
#
# Global measures characterize the overall behavior of a feature or model and are commonly used for [model checking](MachineLearning_glossary_m_r.ipynb#model-checking) and validation.
#
# Used in:
# - [Model Checks for Global Accuracy](MachineLearning_model_checking.ipynb#spatial-modeling)
#
# Contrast with:
# - [Local Measure](MachineLearning_glossary_g_l.ipynb#local-measure)
#
#
# #### **Gradient Boosting Model**
#
# Machine learning [prediction](MachineLearning_glossary_m_r.ipynb#prediction) model that results from posing a [boosting model](MachineLearning_glossary_a_c.ipynb#boosting-model) as a gradient descent optimization problem.
#
# For boosting,
#
# * at each step, $k$, a new model is fit to improve the current estimator by reducing the [prediction error](MachineLearning_glossary_m_r.ipynb#prediction-error)
#
# * the model $h_k(X_1,\ldots,X_m)$ is fit to the residual errors or, more generally, the negative gradient of the [loss function](MachineLearning_glossary_g_l.ipynb#loss-function)
#
# We assign a loss function, $L$,
#
# $$
# L\left(y,F(X)\right) = \frac{\left(y - F(X)\right)^2}{2}
# $$
#
# and minimize the $\ell_2$ loss function,
#
# $$
# J = \sum_{i=1}^{n} L\left(y_i,F_k(X_i)\right)
# $$
#
# by adjusting our model estimator $F(X)$ over the training data.
#
# We can take the partial derivative of the loss with respect to our model estimate,
#
# $$
# \frac{\partial J}{\partial F(X_i)} = F(X_i)-y_i
# $$
#
# The residuals can be interpreted as negative gradients,
#
# $$
# y_i-F(X_i)=-\frac{\partial J}{\partial F(X_i)}
# $$
#
# Therefore, fitting a new model to the residuals is equivalent to fitting a model to the negative gradient of the loss function.
#
# The gradient descent update is,
#
# $$
# F_{k+1}(X_i)=F_k(X_i)+h_k(X_i)
# $$
#
# where the new model $h_k(X_i)$ approximates the negative gradient,
#
# $$
# F_{k+1}(X_i)=F_k(X_i)+y_i-F_k(X_i)
# $$
#
# or equivalently,
#
# $$
# F_{k+1}(X_i)=F_k(X_i)-\frac{\partial J}{\partial F_k(X_i)}
# $$
#
# The general gradient descent form is,
#
# $$
# \phi_{k+1}=\phi_k-\rho\frac{\partial J}{\partial \phi_k}
# $$
#
# where $\phi_k$ is the current state, $\rho$ is the learning rate, $J$ is the loss function, and $\phi_{k+1}$ is the updated estimator state.
#
# The prediction residual at the training data provides the gradient direction that guides each new model. Therefore, gradient boosting performs,
#
# * fitting a sequence of models to the negative gradients of the loss function
#
# By approaching boosting as a gradient descent problem, we can apply different loss functions depending on the [prediction](MachineLearning_glossary_m_r.ipynb#prediction) problem and desired robustness.
#
# * $\ell_2$ loss,
#
# $$
# L(y,F(X))=\frac{(y-F(X))^2}{2}
# $$
#
# is commonly used because it provides a smooth optimization objective, but it is sensitive to outliers.
#
# The negative gradient is,
#
# $$
# -\frac{\partial J}{\partial F_k(X_i)}=y_i-F_k(X_i)
# $$
#
# * $\ell_1$ loss,
#
# $$
# L(y,F(X))=|y-F(X)|
# $$
#
# is more robust to outliers.
#
# The negative subgradient is,
#
# $$
# -\frac{\partial J}{\partial F_k(X_i)} = sign(y_i-F_k(X_i))
# $$
#
# * other loss functions include Huber loss, which combines the robustness of $\ell_1$ loss with the smooth optimization properties of $\ell_2$ loss
#
# Gradient boosting can be conceptionalized as,
#
# * a sequence of addivite weak learners, where each learner is trained to correct the remaining errors of the previous ensemble.
#
# Used in:
# - [Gradient Boosting Modeling Description and Demonstration](MachineLearning_gradient_boosting.ipynb#gradient-boosting-methods)
#
# Also see:
# - [Boosting Model](MachineLearning_glossary_a_c.ipynb#boosting-model)
# - [Loss Function](MachineLearning_glossary_g_l.ipynb#loss-function)
# - [Gradient-based Optimization](MachineLearning_glossary_g_l.ipynb#gradient-based-optimization)
#
#
# #### **Gradient-based Optimization**
#
# A method to train [model parameter](MachineLearning_glossary_m_r.ipynb#model-parameter)s by iteratively minimizing a [loss function](MachineLearning_glossary_g_l.ipynb#loss-function). The general steps include,
#
# 1. initialize model parameters with random or informed starting values
#
# 2. calculate the loss function for the current model parameters
#
# 3. calculate the loss function gradient, which indicates the direction of steepest increase in loss. For many models, the analytical gradient is not available, and numerical approximation or automatic differentiation may be used.
#
# For numerical calculation of a local loss function derivative,
#
# $$
# \nabla L(y_{\alpha}, F(X_{\alpha}, b_1)) =
# \frac{L(y_{\alpha},F(X_{\alpha},b_1+\epsilon))-L(y_{\alpha},F(X_{\alpha},b_1-\epsilon))}{2\epsilon}
# $$
#
# 4. update the parameter estimate by stepping in the direction that decreases the loss function,
#
# $$
# \hat{b}_{1,t+1}=\hat{b}_{1,t}-r\nabla L(y_{\alpha},F(X_{\alpha},b_1))
# $$
#
# where $r$ is the learning rate or step size, $\hat{b}_{1,t}$ is the current model parameter estimate, and $\hat{b}_{1,t+1}$ is the updated parameter estimate.
#
# Important concepts in gradient-based optimization include,
#
# * gradient search convergence - the optimization process attempts to find a minimum of the loss function; depending on the loss landscape, this may be a local minimum, global minimum, or stationary point
#
# * gradient search step size - the learning rate $r$ controls the size of each optimization step; if $r$ is too small, convergence may be slow, while if $r$ is too large, the optimization may overshoot the minimum or diverge
#
# * multiple model parameters - gradients are calculated for all model parameters and represented as a gradient vector,
#
# $$
# \nabla L(y_{\alpha},F(X_{\alpha},b_1,b_2))=\left[\begin{matrix}\frac{\partial L}{\partial b_1}\\\frac{\partial L}{\partial b_2}\end{matrix}\right]
# $$
#
# * exploration of parameter space - optimization for machine learning model training is an exploration of a high-dimensional parameter space to identify parameter values that minimize the loss function
#
# * loss function definition - the loss function is typically an error metric that summarizes [prediction error](MachineLearning_glossary_m_r.ipynb#prediction-error) over the training data
#
# Used in:
# - [Gradient Descent Optimization for Training LASSO Regression Description and Demonstration](MachineLearning_LASSO_regression.ipynb#gradient-descent-optimization)
# - [Gradient Descent Optimization for Training Neural Networks Regression Description and Demonstration](MachineLearning_ANN.ipynb#training-networks-steps)
#
# Also see:
# - [Gradient Boosting Model](MachineLearning_glossary_g_l.ipynb#gradient-boosting-model)
#
#
# #### **Graph**
#
# A mathematical structure that represents data and relationships between data samples, where each [sample](MachineLearning_glossary_s_z.ipynb#sample) is represented as a node and connections between samples are represented as edges.
#
# For a graph,
#
# * nodes - represent samples, entities, or observations
#
# * edges - represent pairwise relationships or connections between nodes
#
# * edge [weight](MachineLearning_glossary_s_z.ipynb#weight)s - can represent the strength, distance, similarity, or other characteristics of the relationship
#
# For an undirected graph, edges are bidirectional, meaning the relationship is symmetric between connected nodes.
#
# Graph applications include,
#
# * providing a convenient format to represent and summarize complex data structures and relationships
#
# * informing clustering analysis methods, such as [spectral clustering](MachineLearning_glossary_s_z.ipynb#spectral-clustering)
#
# * enabling [prediction](MachineLearning_glossary_m_r.ipynb#prediction) models that incorporate relational information, such as [graph neural network](MachineLearning_glossary_g_l.ipynb#graph-neural-network)
#
# Used in:
# - [Graphs for Spectral Clustering Description and Demonstration](MachineLearning_spectral_clustering.ipynb#spectral-clustering-method)
#
# Also see:
# - [Spectral Clustering](MachineLearning_glossary_s_z.ipynb#spectral-clustering)
#
#
# #### **Graph Laplacian**
#
# Matrix representing a [graph](MachineLearning_glossary_g_l.ipynb#graph) by integrating connections between graph nodes, samples, number of connections for each graph nodes, samples. Calculated as,
#
# $$
# L = D - A
# $$
#
# degree matrix, $D$, minus adjacency matrix, $A$, where,
#
# * [degree matrix](MachineLearning_glossary_d_f.ipynb#degree-matrix), $𝐷$ - degree of connection for each node
#
# * [adjacency matrix](MachineLearning_glossary_a_c.ipynb#adjacency-matrix), $𝐴$ - specific connections between nodes
#
# Graph aplacian matrices are commonly used in,
#
# * [spectral clustering](MachineLearning_glossary_s_z.ipynb#spectral-clustering)
#
# Used in:
# - [Spectral Clustering Description and Demonstration](MachineLearning_spectral_clustering.ipynb#calculate-adjacency-degree-and-graph-laplacian-matrices)
#
# Also see:
# - [Adjacency Matrix](MachineLearning_glossary_a_c.ipynb#adjacency-matrix)
# - [Affinity Matrix](MachineLearning_glossary_a_c.ipynb#affinity-matrix)
# - [Graph](MachineLearning_glossary_g_l.ipynb#graph)
#
#
# #### **Graph Neural Network**
#
# A [neural network](MachineLearning_glossary_m_r.ipynb#neural-network) architecture designed to learn from graph-structured data by exchanging information between connected nodes.
#
# Graph neural networks learn representations by,
#
# * aggregating information from neighboring nodes through [graph](MachineLearning_glossary_g_l.ipynb#graph) connections
#
# * updating node representations using learnable weights, [activation function](MachineLearning_glossary_a_c.ipynb#activation-function)s, and [backpropagation](MachineLearning_glossary_a_c.ipynb#backpropagation)
#
# Applications include,
#
# * social and communication networks
#
# * molecular and biological networks
#
# * transportation and infrastructure networks
#
# * geological fault, fracture, and well networks
#
# Contrast with:
# - [Convolutional Neural Network](MachineLearning_glossary_a_c.ipynb#convolutional-neural-network)
# - [Recurrent Neural Network](MachineLearning_glossary_m_r.ipynb#recurrent-neural-network)
#
# Also see:
# - [Neural Network](MachineLearning_glossary_m_r.ipynb#neural-network)
# - [Activation Function](MachineLearning_glossary_a_c.ipynb#activation-function)
# - [Backpropagation](MachineLearning_glossary_a_c.ipynb#backpropagation)
#
#
# #### **Gridded Data**
#
# Data represented at regularly spaced locations over a 2D [area of interest](MachineLearning_glossary_a_c.ipynb#area-of-interest) or 3D [volume of interest](MachineLearning_glossary_s_z.ipynb#volume-of-interest), commonly used to represent maps and spatial models.
#
# Gridded data are characterized by,
#
# * regularly spaced locations defined by grid dimensions and cell spacing
#
# * exhaustive coverage over the modeled domain, where every grid location contains a value or assigned missing value
#
# * implicit spatial relationships between neighboring grid locations
#
# Gridded data may be stored as,
#
# * a .csv comma-delimited file, where data may be represented as a matrix with $n_y$ rows and $n_x$ columns
#
# * binary formats for more compact storage and faster processing, although these files are not human readable
#
# Gridded data are commonly visualized directly, for example,
#
# * image representations using functions such as matplotlib's imshow
#
# * contour maps and other spatial visualization methods
#
# Examples of gridded data include,
#
# * geological interpretation-based maps
#
# * acoustic impedance models inverted from [seismic](MachineLearning_glossary_s_z.ipynb#seismic) reflection surveys
#
# For spatial modeling problems,
#
# * model outputs or [response feature](MachineLearning_glossary_m_r.ipynb#response-feature)s are often estimated over a regular grid to create continuous maps or 3D models
#
# Also see:
# - [Volume of Interest](MachineLearning_glossary_s_z.ipynb#volume-of-interest)
# - [Area of Interest](MachineLearning_glossary_a_c.ipynb#area-of-interest)
# - [Seismic](MachineLearning_glossary_s_z.ipynb#seismic)

# %% [markdown]
# #### **Hard Data**
#
# [Data](MachineLearning_glossary_d_f.ipynb#data) that is treated as certain due to having a high degree of certainty relative to other available information sources. Hard data usually comes from direct measurement or observation of the feature of interest, for example,
#
# * [Core](MachineLearning_glossary_a_c.ipynb#core)-based porosity, permeability, mineralogy, and [facies](MachineLearning_glossary_d_f.ipynb#facies) observations
#
# * direct measurements of grade from drill core [sample](MachineLearning_glossary_s_z.ipynb#sample)s
#
# * laboratory measurements of rock or fluid properties
#
# Hard data is considered sufficiently reliable that uncertainty in the measurement is commonly not explicitly modeled or integrated into subsequent workflows. Note, hard data is not necessarily error-free;
#
# * it represents information that is treated as certain for the purpose of the analysis.
#
# Hard data generally has high resolution (small scale, volume support), but poor spatial coverage because only an extremely small proportion of the [population](MachineLearning_glossary_m_r.ipynb#population) is directly sampled. For example,
#
# * Core coverage deepwater oil and gas - well core may [sample](MachineLearning_glossary_s_z.ipynb#sample) only one five hundred millionth to one five billionth of a deepwater reservoir, assuming 3 inch diameter cores with 10% core coverage in vertical wells with 500 m to 1,500 m spacing
#
# * Core coverage mining grade control - diamond drill hole cores may sample one eight thousandth to one thirty thousandth of an ore body, assuming HQ 63.5 mm diameter cores with 100% core coverage in vertical drill holes with 5 m to 10 m spacing
#
# Hard data provides the most direct calibration of subsurface models but must be integrated with other information sources to overcome limited spatial coverage.
#
# Used in:
# TBD
#
# Contrast with:
# - [Soft Data](MachineLearning_glossary_s_z.ipynb#soft-data)
#
#
# #### **Harmonic Mean**
#
# A measure of central tendency that calculates the reciprocal of the arithmetic mean of reciprocals, commonly used when,
#
# * averaging rates or ratios
#
# * scale up, change of volume support for permeability, given flow across beds
#
# For $n$ values, the harmonic mean is,
#
# $$
# H = \frac{n}{\sum_{i=1}^{n}\frac{1}{x_i}}
# $$
#
# The harmonic mean gives greater weight to smaller values and is useful when low values should strongly influence the average,
#
# * such as the [F1-score](MachineLearning_glossary_d_f.ipynb#f1-score) that balances [precision](MachineLearning_glossary_m_r.ipynb#precision) and [recall][precision](MachineLearning_glossary_m_r.ipynb#recall).
#
# Also see:
# - [F1-score](MachineLearning_glossary_d_f.ipynb#f1-score)
# - [Precision](MachineLearning_glossary_m_r.ipynb#precision)
# - [Recall](MachineLearning_glossary_m_r.ipynb#recall)
#
#
# #### **Hermite Polynomial**
#
# A family of orthogonal polynomials on the real number line, commonly used for representing functions with Gaussian-distributed variables.
#
# | Order | Hermite Polynomial $H_n(x)$ |
# |--------------|-----------------------------------------|
# | 0th Order | $H_0(x)=1$ |
# | 1st Order | $H_1(x)=x$ |
# | 2nd Order | $H_2(x)=x^2-1$ |
# | 3rd Order | $H_3(x)=x^3-3x$ |
# | 4th Order | $H_4(x)=x^4-6x^2+3$ |
#
# These polynomials are orthogonal with respect to the weighting function,
#
# $$
# w(x)=e^{-\frac{x^2}{2}}
# $$
#
# which is proportional to the standard Gaussian [probability density function](MachineLearning_glossary_m_r.ipynb#probability-density-function) without the scaling factor,
#
# $$
# \frac{1}{\sqrt{2\pi}}
# $$
#
# The definition of orthogonality is,
#
# $$
# \int_{-\infty}^{\infty} H_m(x)H_n(x)w(x)\,dx=0
# $$
#
# for $m \neq n$.
#
# Therefore, Hermite polynomials are orthogonal over the interval $[-\infty,\infty]$ with respect to the standard normal probability distribution.
#
# By applying Hermite polynomials instead of regular polynomial terms for polynomial [basis expansion](MachineLearning_glossary_a_c.ipynb#basis-expansion) in [polynomial regression](MachineLearning_glossary_m_r.ipynb#polynomial-regression), we reduce multicollinearity between the [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s,
#
# * recall, polynomial basis expansion creates correlated predictor features because terms such as $x$, $x^2$, $x^3$ are not independent
#
# * orthogonal polynomial bases create transformed features that are uncorrelated under the specified weighting function
#
# Orthogonal polynomial bases can improve numerical stability and interpretation of polynomial [regression](MachineLearning_glossary_m_r.ipynb#regression)
#  models, especially when predictors follow approximately Gaussian distributions.
#
# Used in:
# - [Hermite Polynomials for Polynomial Regression Description and Demonstration](MachineLearning_polynomial_regression.ipynb#hermite-polynomials)
#
# Also see:
# - [Basis Expansion](MachineLearning_glossary_a_c.ipynb#basis-expansion)
# - [Polynomial Regression](MachineLearning_glossary_m_r.ipynb#polynomial-regression)
#
#
# #### **Heuristic Algorithm**
#
# A practical algorithm that uses approximations, rules, or strategies to find a good solution to a difficult problem without guaranteeing the optimal solution.
#
# A heuristic algorithm represents a compromise between optimality, accuracy, computational cost, and practicality,
#
# * trading an exact solution for a faster solution that is often sufficiently accurate for the application
#
# Heuristic algorithms are commonly applied in,
#
# * machine learning
#
# * computer science
#
# * mathematical optimization
#
# For example,
#
# * the optimal solution for $k$-means clustering involves searching a large solution space of possible cluster assignments. Since the number of possible assignments grows exponentially with the number of samples, a heuristic iterative algorithm is applied to efficiently find a practical clustering solution.
#
# Used in:
# - [Heuristic for Training k-Means Clustering](MachineLearning_clustering.ipynb#solution-heuristic)
#
# Also see:
# - [Model Parameter Training](MachineLearning_glossary_m_r.ipynb#model-parameter-training)
#
#
# #### **Hierarchical Clustering**
#
# A family of clustering methods that construct a hierarchy of nested clusters, typically represented by a dendrogram,
#
# * representing the cluster solutions for $k = [1, 2, \ldots, n-1, n]$ simultaneously
#
# * dendrogram provides a visual representation of the cluster hierarchy and allows the user to select the number of clusters by choosing a linkage distance (cut height)
#
# The linkage distance depends on the linkage criterion used:
#
# * single linkage - minimum distance between clusters
#
# * complete linkage - maximum distance between clusters
#
# * average linkage - [average](MachineLearning_glossary_a_c.ipynb#average) pairwise distance
#
# * Ward's linkage - increase in within-cluster [variance](MachineLearning_glossary_s_z.ipynb#variance) (often the most popular)
#
# Hierarchical clustering determines cluster groups through a sequence of merges or splits, rather than directly optimizing a fixed partition of the data.
#
# Common approaches include,
#
# * agglomerative hierarchical clustering - start with $n$ clusters, where each data [sample](MachineLearning_glossary_s_z.ipynb#sample) is assigned to its own cluster, and iteratively merge the most similar clusters until a stopping criterion is reached
#
# * divisive hierarchical clustering - start with all data assigned to a single cluster, and iteratively divide clusters into smaller clusters until a stopping criterion is reached
#
# Compared with [partitional clustering](MachineLearning_glossary_m_r.ipynb#partitional-clustering) methods,
#
# * hierarchical clustering produces a hierarchy of cluster solutions rather than a single clustering solution
#
# * $k$-means clustering is a partitional clustering method that iteratively updates cluster assignments while directly optimizing a single partition of the data
#
# * once clusters have been merged or split, hierarchical clustering generally does not revisit earlier decisions, making the method computationally efficient but potentially sensitive to early decisions
#
# A helpful summary of clustering methods,
#
# * partitional clustering $\rightarrow$ Find one best partition of the data.
#
# * hierarchical clustering $\rightarrow$ Build a tree of nested clusters.
#
# * density-based clustering $\rightarrow$ Find regions of high sample density.
#
# Also see:
# - [Partitional Clustering](MachineLearning_glossary_m_r.ipynb#partitional-clustering)
# - [Density-based Clustering](MachineLearning_glossary_d_f.ipynb#density-based-clustering)
#
#
# #### **Histogram**
#
# A bar chart representation of a [univariate](MachineLearning_glossary_s_z.ipynb#univariate) [statistical distribution](MachineLearning_glossary_s_z.ipynb#statistical-distribution) showing the frequency of [sample](MachineLearning_glossary_s_z.ipynb#sample)s over an exhaustive set of bins spanning the range of possible values.
#
# These are the steps to build a histogram,
#
# 1. Divide the [continuous feature](MachineLearning_glossary_a_c.ipynb#continuous-feature) range of possible values into $K$ equal size bins, $\Delta x$:
#
# $$
# \Delta x = \left( \frac{x_{max} - x_{min}}{K} \right)
# $$
#
# or use available category labels for [categorical feature](MachineLearning_glossary_a_c.ipynb#categorical-feature)s.
#
# 2. Count the number of samples (frequency) in each bin, $n_k$, $\forall k=1,\ldots,K$.
#
# 3. Plot frequency versus the bin label (use bin centroid for continuous features).
#
# The histogram y-axis represents frequency. When normalized by the total number of samples,
#
# $$
# p_k = \frac{n_k}{n}
# $$
#
# the result is a [normalized histogram](MachineLearning_glossary_m_r.ipynb#normalized-histogram), where the y-axis represents probability.
#
# * for [discrete feature](MachineLearning_glossary_d_f.ipynb#discrete-feature)s, the normalized histogram is an empirical [probability mass function](MachineLearning_glossary_m_r.ipynb#probability-mass-function)
#
# * for continuous features, the normalized histogram represents probability mass over intervals; dividing by bin width provides an estimate of the [probability density function](MachineLearning_glossary_m_r.ipynb#probability-density-function)
#
# Additional comments about histograms,
#
# * typically plotted as bar charts
#
# * 2D histograms use a orthonormal view columns with 2 axes for features and along with the frequency axis, but not often used to attempt to visualize [bivariate](MachineLearning_glossary_a_c.ipynb#bivariate) relationships
#
# Used in:
# - [Histogram Description and Demonstration](MachineLearning_univariate_analysis.ipynb#histogram)
#
# Also see:
# - [Normalized Histogram](MachineLearning_glossary_m_r.ipynb#normalized-histogram)
#
#
# #### **Holdout Cross Validation**
#
# A [cross validation](MachineLearning_glossary_a_c.ipynb#cross-validation) method that partitions the available data into one training subset and one withheld testing subset.
#
# Holdout validation is simple and computationally efficient but may produce variable performance estimates because the evaluation depends on a single train-test split.
#
# Used in:
# - [Holdout Validation Tuning Ridge Regression Demonstration](MachineLearning_ridge_regression.ipynb#model-hyperparameter-tuning)
# - [Holdout Validation Tuning LASSO Regression Demonstration](MachineLearning_LASSO_regression.ipynb#visualize-the-data)
# - [Holdout Validation Tuning k-Nearest Neighbours Demonstration](MachineLearning_knearest_neighbours.ipynb#k-nearest-neighbours-hyperparameters)
# - [Holdout Validation Tuning Decision Tree Demonstration](MachineLearning_decision_tree.ipynb#train-and-test-split)
#
# Also see:
# - [Cross Validation](MachineLearning_glossary_a_c.ipynb#cross-validation)
#
# Contrast with:
# - [K-fold Cross Validation](MachineLearning_glossary_g_l.ipynb#k-fold-cross-validation)
#
#
# #### **Hybrid Model**
#
# A model that combines both [deterministic model](MachineLearning_glossary_d_f.ipynb#deterministic-model) and [stochastic model](MachineLearning_glossary_s_z.ipynb#stochastic-model) components.
#
# Hybrid models separate predictable structure from uncertain variability by combining,
#
# * deterministic components - representing known relationships, physical processes, expert interpretation, or data-driven [trend](MachineLearning_glossary_s_z.ipynb#trend)s
#
# * stochastic components - representing spatial variability, uncertainty, and unresolved processes that cannot be deterministically modeled
#
# Most geostatistical models are hybrid models. For example, an additive deterministic [trend model](MachineLearning_glossary_s_z.ipynb#trend-model) and stochastic residual model:
#
# $$
# Z(\mathbf{u}) = m(\mathbf{u}) + R(\mathbf{u})
# $$
#
# where $m(\mathbf{u})$ represents the deterministic [trend](MachineLearning_glossary_s_z.ipynb#trend) and $R(\mathbf{u})$ represents the stochastic residual.
#
# Other examples include,
#
# * deterministic geological frameworks combined with stochastic property simulation
#
# * physics-based models calibrated or conditioned with stochastic [uncertainty model](MachineLearning_glossary_s_z.ipynb#uncertainty-modeling)s
#
# * data-driven predictive models combined with probabilistic uncertainty models
#
# Used in:
# TBA - deterministic trends and data nonstationarity discussion

# %% [markdown]
# #### **Independence**
#
# Two random events, $A$ and $B$, are independent if knowledge of one event provides no information about the likelihood of the other event. Mathematically, events are independent if and only if the following equivalent relationships are true,
#
# 1. [Joint probability](MachineLearning_glossary_g_l.ipynb#joint-probability):
#
# $$
# P(A \cap B) = P(A) \cdot P(B)
# $$
#
# 2. [Conditional probability](MachineLearning_glossary_a_c.ipynb#conditional-probability):
#
# $$
# P(A|B) = P(A)
# $$
#
# 3. Conditional probability:
#
# $$
# P(B|A) = P(B)
# $$
#
# If any of these relationships are violated, then the events are dependent, indicating that some form of relationship exists between them.
#
# * Note that dependence does not necessarily imply [causation](MachineLearning_glossary_a_c.ipynb#causation).
#
# In spatial modeling, independence indicates that knowing one feature or event provides no additional information about another feature or event. For example,
#
# * spatially independent [sample](MachineLearning_glossary_s_z.ipynb#sample)s have no correlation over the specified lag distance.
#
# Used in:
# - [Independence Checks Description and Demonstration](MachineLearning_probability.ipynb#independent-events)
#
#
# #### **Indicator Transform**
#
# Indicator coding converts a [random variable](MachineLearning_glossary_m_r.ipynb#random-variable) into a probability relative to a category or a threshold.
#
# For a [categorical feature](MachineLearning_glossary_a_c.ipynb#categorical-feature), the indicator answers the question,
#
# * what is the probability that the data value or [realization](MachineLearning_glossary_m_r.ipynb#realization) belongs to a specific category?
#
# The indicator transform is,
#
# $$
# i(\mathbf{u}; z_k) =
# \begin{cases}
# 1, & \text{if } Z(\mathbf{u}) = z_k \\
# 0, & \text{if } Z(\mathbf{u}) \ne z_k
# \end{cases}
# $$
#
# For example,
#
# * given category $z_2 = 2$, and data at $\mathbf{u}_1$ with $z(\mathbf{u}_1)=2$, then $i(\mathbf{u}_1;z_2)=1$
#
# * given category $z_1 = 1$, and a random variable away from data at $\mathbf{u}_2$, the probability that the realization belongs to category $z_1$ is $P(Z(\mathbf{u}_2)=z_1)=0.23$, therefore $i(\mathbf{u}_2;z_1)=0.23$
#
# For a [continuous feature](MachineLearning_glossary_a_c.ipynb#continuous-feature), the indicator answers the question,
#
# * what is the probability that the realization is less than or equal to a threshold?
#
# The indicator transform is,
#
# $$
# i(\mathbf{u}; z_k) =
# \begin{cases}
# 1, & \text{if } Z(\mathbf{u}) \le z_k \\
# 0, & \text{if } Z(\mathbf{u}) > z_k
# \end{cases}
# $$
#
# For example,
#
# * given threshold $z_1 = 6\%$, and data at $\mathbf{u}_1$ with $z(\mathbf{u}_1)=8\%$, then $i(\mathbf{u}_1;z_1)=0$
#
# * given threshold $z_4 = 18\%$, and a random variable away from data, $Z(\mathbf{u}_2)\sim N(\mu=16\%,\sigma=3\%)$, then
#
# $$
# i(\mathbf{u}_2;z_4)=P\!\left(Z(\mathbf{u}_2)\le18\%\right)=0.75
# $$
#
# The indicator transform may be applied to an entire [random function](MachineLearning_glossary_m_r.ipynb#random-function) by transforming the random variable at every location. Indicator transforms provide the foundation for indicator kriging, indicator variograms, and indicator simulation.
#
# Note, the indicator transform,
#
# * may be applied to encode data softness, in this case the data values are not strickly 0 or 1 with respect to each threshold or category at the a data location.
#
# * may also be applied to encode a constriant relationship, e.g., data value cannot be category 1, but there is no information about category 2 nor 3, or data value is between 0.1 and 0.4, but there is no information within this interval.
#
# * is analogous to the [one-hot encoding](MachineLearning_glossary_m_r.ipynb#one-hot-encoding) approach for [feature engineering](MachineLearning_glossary_d_f.ipynb#feature-engineering) commonly used to deal with categorical features in machine learning.
#
# Used in:
# - [Facies as a Variable or Feature Discussion](MachineLearning_concepts.ipynb#machine-learning-prerequisite-definitions)
# - [Indicator Transform Description and Demonstration](MachineLearning_feature_transformations.ipynb#binary-or-indictor-transform)
#
# Also see:
# - [Binary Transform](MachineLearning_glossary_a_c.ipynb#binary-transform)
#
#
# #### **Inertia**
#
# A label for the [k-Means clustering](MachineLearning_glossary_g_l.ipynb#k-means-clustering) [loss function](MachineLearning_glossary_g_l.ipynb#loss-function) that summarizes the total within-cluster variation by measuring the squared distance between each [sample](MachineLearning_glossary_s_z.ipynb#sample) and the [prototype](MachineLearning_glossary_m_r.ipynb#prototype) (centroid) of its assigned cluster,
#
# $$
# I = \sum_{i=1}^{K} \sum_{x_j \in C_i} \|x_j - \mu_i\|^2
# $$
#
# where,
#
# * $K$ is the total number of clusters,
#
# * $C_i$ represents the set of samples assigned to the $i^{th}$ cluster,
#
# * $x_j$ represents a data sample belonging to cluster $C_i$,
#
# * $\mu_i$ is the prototype (centroid) of cluster $C_i$,
#
# * $\|x_j - \mu_i\|^2$ is the squared Euclidean distance between sample $x_j$ and the cluster prototype $\mu_i$.
#
# The samples, prototypes, and distance calculations are performed in $m$-dimensional feature space, where each observation is represented by features $X_1,\ldots,X_m$.
#
# * by minimizing inertia, k-means finds clusters with the smallest possible within-cluster sum of squared distances, producing compact groups of similar samples.
#
# * since the total [variance](MachineLearning_glossary_s_z.ipynb#variance) of the dataset is fixed, reducing within-cluster variation generally results in greater separation between clusters.
#
# Used in:
# - [Inertia as k-Means Clustering Loss Function Description and Demonstration](MachineLearning_clustering.ipynb#k-means-clustering-method)
#
# Also see:
# - [k-Means Clustering](MachineLearning_glossary_g_l.ipynb#k-means-clustering)
# - [Loss Function](MachineLearning_glossary_g_l.ipynb#loss-function)
# - [Prototype](MachineLearning_glossary_m_r.ipynb#prototype)
#
#
# #### **Inference**
#
# The process of using a [sample](MachineLearning_glossary_s_z.ipynb#sample) drawn from a [population](MachineLearning_glossary_m_r.ipynb#population) to infer properties of the entire population. For example,
#
# * given sparsely sampled well data (the sample) with porosity [well log](MachineLearning_glossary_s_z.ipynb#well-log) measurements, infer the porosity [histogram](MachineLearning_glossary_g_l.ipynb#histogram) of the entire reservoir (the population)
#
# * given sparsely sampled drill hole data (the sample) with gold grade measurements, infer the gold grade distribution and spatial variability throughout the ore body (the population)
#
# * in [geostatistics](MachineLearning_glossary_g_l.ipynb#geostatistics), inference includes estimating statistical properties (e.g., [histogram](MachineLearning_glossary_g_l.ipynb#histogram)s, [variogram](MachineLearning_glossary_s_z.ipynb#variogram)s, and [trend](MachineLearning_glossary_s_z.ipynb#trend)s) as well as spatial models away from the sampled locations
#
# * the statistical discipline devoted to inference is known as statistical inference
#
# Inference is a broad topic encompassing many statistical methods. For this e-book, we adopt this simplified, practical definition focused on subsurface characterization and modeling.
#
# Used in:
# - [Comparison of Inference and Prediction](MachineLearning_concepts.ipynb#machine-learning-prerequisite-definitions)
#
# Compare with:
# - [Prediction](MachineLearning_glossary_m_r.ipynb#prediction)
#
#
# #### **Inlier**
#
# A [regression](MachineLearning_glossary_m_r.ipynb#regression) model accuracy metric based on the proportion of testing data with [prediction error](MachineLearning_glossary_m_r.ipynb#prediction-error)s within a specified margin, $\epsilon$.
#
# The inlier ratio is,
#
# $$
# I_R=\frac{1}{n_{\text{test}}}\sum_{i=1}^{n_{\text{test}}}I(y_i,\hat{y}_i)
# $$
#
# where the indicator function is,
#
# $$
# I(y_i,\hat{y}_i)=\begin{cases}1, & \text{if } |y_i-\hat{y}_i|\leq\epsilon \\0, & \text{otherwise}\end{cases}
# $$
#
# This provides a simple and intuitive measure of prediction accuracy by reporting the proportion of testing (or training) data with [prediction](MachineLearning_glossary_m_r.ipynb#prediction)s that are sufficiently accurate for the application.
#
# Important considerations include,
#
# * choice or [margin](MachineLearning_glossary_m_r.ipynb#margin) - the choice of the acceptable prediction margin, $\epsilon$, is subjective and should reflect the accuracy requirements of the specific application
#
# * impact of outliers - unlike metrics such as [mean square error](MachineLearning_glossary_m_r.ipynb#mean-square-error) or [mean absolute error](MachineLearning_glossary_m_r.ipynb#mean-absolute-error), the inlier ratio does not distinguish between small and large errors once the prediction falls outside the specified margin
#
# Used in:
# - [Inlier Description](MachineLearning_training_tuning.ipynb#inlier-ratio)
#
# Contrast with:
# - [Outlier](MachineLearning_glossary_m_r.ipynb#outlier)
#
#
# #### **Instance-based Learning**
#
# Family of predictive machine learning models that,
#
# * makes [prediction](MachineLearning_glossary_m_r.ipynb#prediction)s by comparing a new observation, represented by the [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s $x_1,\ldots,x_m$, with similar observations stored in the training data.
#
# * also known as memory-based learning
#
# Instance-based learning is characterized by,
#
# * lazy learning training strategy - instance-based methods generally defer learning until [prediction](MachineLearning_glossary_m_r.ipynb#prediction) time by storing the training data rather than fitting an explicit predictive model, the model is the training data with the hyperparameters
#
# * analogy-based prediction - predictions are made directly from the most similar training observations rather than from an explicit mathematical model
#
# * similarity measure - predictions depend on a measure of similarity or distance between observations, such as Euclidean distance
#
# * [computational complexity](MachineLearning_glossary_a_c.ipynb#computational-complexity) - prediction cost generally increases with the number of training observations, $n$, the number of predictor features, $m$, and, for nearest-neighbor methods, the number of neighbors, $k$
#
# Examples of instance-based learning predictive machine learning models include,
#
# * $k$-nearest neighbors (KNN) regression
#
# * $k$-nearest neighbors (KNN) [classification](MachineLearning_glossary_a_c.ipynb#classification)
#
# Used in:
# - [k-Nearest Neighbors](MachineLearning_glossary_g_l.ipynb#k-nearest-neighbours)
#
# Contrast with:
# - [Eager Learning](MachineLearning_glossary_d_f.ipynb#eager-learning)
#
#
# #### **Intersection of Events**
#
# The event in which two or more events occur together. For two events, $A$ and $B$, the intersection is denoted by,
#
# $$
# A \cap B
# $$
#
# The probability of the intersection is,
#
# $$
# P(A \cap B) = P(A,B) = P(A \text{ and } B)
# $$
#
# where we may state, "probability of A and B". If $A$ and $B$ are [independent](MachineLearning_glossary_g_l.ipynb#independence), then the [joint probability](MachineLearning_glossary_g_l.ipynb#joint-probability) simplifies to,
#
# $$
# P(A,B) = P(A) \cdot P(B)
# $$
#
# Without the assumption of independence, we apply the [multiplication rule](MachineLearning_probability.ipynb#probability-multiplication-rule),
#
# $$
# P(A,B) = P(B|A) \cdot P(A)
# $$
#
# or equivalently,
#
# $$
# P(A,B) = P(A|B) \cdot P(B)
# $$
#
# Used in:
# - [Probability Addition Rule Definition and Demonstration](MachineLearning_probability.ipynb#marginal-conditional-and-joint-probabilities)
#
# See also:
# - [Joint Probability](MachineLearning_glossary_g_l.ipynb#joint-probability)
# - [Multiplication Rule](MachineLearning_probability.ipynb#probability-multiplication-rule)
# - [Independence](MachineLearning_glossary_g_l.ipynb#independence)
#
#
# #### **Irreducible Error**
#
# The additive component of the [expected testing mean square error](MachineLearning_glossary_d_f.ipynb#expected-test-mean-square-error) that cannot be eliminated by improving the [prediction](MachineLearning_glossary_m_r.ipynb#prediction) model.
#
# $$
# \mathbb{E}\!\left[\left(y_0-\hat{f}(x_{0,1}^{(i)},\ldots,x_{0,m}^{(i)})\right)^2\right] =
# \underbrace{\left(\mathbb{E}\!\left[\hat{f}(x_{0,1}^{(i)},\ldots,x_{0,m}^{(i)})\right]-f(x_{0,1}^{(i)},\ldots,x_{0,m}^{(i)})\right)^2}_{\text{Model Bias}^2}
# +
# \underbrace{\mathbb{E}\!\left[\left(\hat{f}(x_{0,1}^{(i)},\ldots,x_{0,m}^{(i)})-\mathbb{E}\!\left[\hat{f}(x_{0,1}^{(i)},\ldots,x_{0,m}^{(i)})\right]\right)^2\right]}_{\text{Model Variance}}
# +
# \underbrace{\sigma_{\epsilon}^{2}}_{\text{Irreducible Error}}
# $$
#
# Irreducible error represents uncertainty that cannot be explained by the available [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s. Sources include,
#
# * missing or unmeasured predictor features
#
# * incomplete sampling of the [predictor feature space](MachineLearning_glossary_m_r.ipynb#predictor-feature-space)
#
# * measurement error in the [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)(s) or [response feature](MachineLearning_glossary_m_r.ipynb#response-feature)s
#
# * inherent randomness or stochastic variation in the underlying process
#
# Irreducible error is the only additive component of the expected testing mean square error that is independent of [model complexity](MachineLearning_glossary_m_r.ipynb#model-complexity).
#
# Irreducible error may be reduced by,
#
# * collecting additional or more informative predictor features
#
# * increasing the quantity and representativeness of the training data
#
# * improving measurement quality to reduce observational error
#
# The component of irreducible error associated with inherent randomness cannot be eliminated by any prediction model.
#
# Used in:
# - [Tuning Model Hyperparameters](MachineLearning_concepts.ipynb#training-and-tuning-predictive-machine-learning-models)
#
# Also see:
# - [Model Bias](MachineLearning_glossary_m_r.ipynb#model-bias)
# - [Model Variance](MachineLearning_glossary_m_r.ipynb#model-variance)
# - [Model Bias–Variance Trade-off](MachineLearning_glossary_m_r.ipynb#model-biasvariance-trade-off)

# %% [markdown]
# #### **Joint Probability**
#
# Probability of an event in which two or more events occur together,
#
# $$
# A \cap B
# $$
#
# The probability of the intersection is,
#
# $$
# P(A \cap B) = P(A,B) = P(A \text{ and } B)
# $$
#
# where we may state, "probability of A and B". If $A$ and $B$ are [independent](MachineLearning_glossary_g_l.ipynb#independence), then the joint probability simplifies to,
#
# $$
# P(A,B) = P(A) \cdot P(B)
# $$
#
# Without the assumption of independence, we apply the [multiplication rule](MachineLearning_probability.ipynb#probability-multiplication-rule),
#
# $$
# P(A,B) = P(B|A) \cdot P(A)
# $$
#
# or equivalently,
#
# $$
# P(A,B) = P(A|B) \cdot P(B)
# $$
#
# Used in:
# - [Marginal, Conditional, and Joint Probability Definition and Demonstration](MachineLearning_probability.ipynb#marginal-conditional-and-joint-probabilities)
#
# See also:
# - [Joint Probability](MachineLearning_glossary_g_l.ipynb#joint-probability)
# - [Multiplication Rule](MachineLearning_probability.ipynb#probability-multiplication-rule)
# - [Independence](MachineLearning_glossary_g_l.ipynb#independence)
#
#
# #### **K-Bins Discretization**
#
# A feature transformation method based on dividing a [continuous feature](MachineLearning_glossary_a_c.ipynb#continuous-feature) into $K$ discrete intervals (bins) over the feature range, then assigning each [sample](MachineLearning_glossary_s_z.ipynb#sample) to a bin. For [one-hot encoding](MachineLearning_glossary_m_r.ipynb#one-hot-encoding) bin representation, a value of 1 is assigned if the sample belongs to a bin and 0 if it is outside the bin.
#
# A feature transformation method based on dividing a continuous feature into $K$ discrete intervals (bins) over the feature range, then assigning each sample to a bin. The output may be either,
#
# * a single bin label indicating the assigned interval
#
# * a one-hot encoding representation with a value of 1 if the sample belongs to a bin and 0 if it is outside the bin
#
# Binning strategies include:
#
# * uniform width bins - divides the feature range into $K$ intervals of equal width,
#
# * quantile bins - divides the feature values into $K$ intervals containing approximately the same number of samples.
#
# This is a continuous range is partitioned into discrete intervals to simplify representation,
#
# * analogous to constructing a [histogram](MachineLearning_glossary_g_l.ipynb#histogram), where the count of samples within each bin forms the height of each bar.
#
# * analogous to posterization in image processing, where continuous pixel intensity or color values are reduced to a smaller number of discrete levels.
#
# Methods and applications that utilize $K$ bins discretization include,
#
# * [basis expansion](MachineLearning_glossary_a_c.ipynb#basis-expansion) to represent nonlinear relationships by transforming features into a higher-dimensional space,
#
# * discretization of continuous features into [categorical feature](MachineLearning_glossary_a_c.ipynb#categorical-feature)s for categorical methods such as the [naive Bayes](MachineLearning_glossary_m_r.ipynb#naive-bayes) [classification](MachineLearning_glossary_a_c.ipynb#classification),
#
# * histogram construction and Chi-square tests for comparing differences between distributions,
#
# * [mutual information](MachineLearning_glossary_m_r.ipynb#mutual-information)-based feature discretization and feature selection.
#
# Used in:
# - [k-Bins Discretization Description and Demonstration](MachineLearning_feature_transformations.ipynb#binary-or-indictor-transform)
#
# Also see:
# - [k-bins Discretization](MachineLearning_glossary_g_l.ipynb#k-bins-discretization)
# - [categorical feature](MachineLearning_glossary_a_c.ipynb#categorical-feature)
#
#
# #### **K-Fold Cross Validation**
#
# A [cross validation](MachineLearning_glossary_a_c.ipynb#cross-validation) method based on partitioning the data into $K$ folds and looping over the folds,
#
# * withhold the current fold as validation data and train the model using the remaining $K-1$ folds,
#
# * calculate the model performance metric over the withheld validation fold,
#
# * aggregate the validation performance over all folds to estimate [model generalization](MachineLearning_glossary_m_r.ipynb#model-generalization) performance.
#
# Relating K-fold cross validation to the holdout method with a single [train and test split](MachineLearning_glossary_s_z.ipynb#train-and-test-split),
#
# * K-fold cross validation provides a more robust performance estimate than a single holdout split by allowing all samples to be used for both training and validation, and averaging performance over folds reduces the sensitivity to a particular train-test partition.
#
# * the relative size of the training and validation datasets is controlled by $K$; for example, $K=4$ produces approximately $25\%$ validation data per fold and $75\%$ training data, while $K=5$ produces approximately $20\%$ validation data per fold and $80\%$ training data.
#
# * K-fold cross validation is commonly applied for estimating model [prediction](MachineLearning_glossary_m_r.ipynb#prediction) accuracy and may also be used to assess uncertainty in model performance and goodness ([Maldonado-Cruz and Pyrcz, 2021](https://www.sciencedirect.com/science/article/pii/S0920410521006343)).
#
# Used in:
# - [Tuning k for k-nearest Neighbours Regression Description and Demonstration](MachineLearning_knearest_neighbours.ipynb#k-nearest-neighbours-hyperparameters)
# - [Pruning Decision Tree Description and Demonstration](MachineLearning_decision_tree.ipynb#tuning-the-tree-model)
# - [Tuning Random Forest Description and Demonstration](MachineLearning_ensemble_trees.ipynb#training-and-tuning-bagging-models)
#
# Compare with:
# - [Cross Validation](MachineLearning_glossary_a_c.ipynb#cross-validation)
#
# Also see:
# - [Holdout Cross Validation](MachineLearning_glossary_g_l.ipynb#holdout-cross-validation)
# - [Leave-One-Out Cross Validation](MachineLearning_glossary_g_l.ipynb#leave-one-out-cross-validation)
# - [Stratified K-fold Cross Validation](MachineLearning_glossary_s_z.ipynb#stratified-k-fold-cross-validation)
#
#
# #### **k-Means Clustering**
#
# An unsupervised machine learning method for cluster analysis that assigns unlabeled data samples into groups by minimizing dissimilarity within clusters, represented by the [inertia](MachineLearning_glossary_g_l.ipynb#inertia) [loss function](MachineLearning_glossary_g_l.ipynb#loss-function),
#
# $$
# I = \sum_{i=1}^{K} \sum_{\alpha \in C_i} ||X_{\alpha} - \mu_i||^2
# $$
#
# where,
#
# * $i$ is the cluster index,
#
# * $K$ is the total number of clusters,
#
# * $C_i$ represents the set of samples assigned to cluster $i$,
#
# * $\alpha$ is the data sample index,
#
# * $X_{\alpha}$ is a data sample,
#
# * $\mu_i$ is the [prototype](MachineLearning_glossary_m_r.ipynb#prototype) (centroid) of cluster $i$,
#
# * $||X_{\alpha}-\mu_i||^2$ is the squared Euclidean distance between a sample and its cluster prototype in $M$-dimensional feature space calculated as,
#
# $$
# ||X_{\alpha}-\mu_i|| =
# \sqrt{\sum_{m=1}^{M}(X_{m,\alpha}-\mu_{m,i})^2}
# $$
#
# Here is a summary of important aspects for k-means clustering,
#
# * [partitional clustering](MachineLearning_glossary_m_r.ipynb#partitional-clustering) - provides a single set of group assignments by partitioning samples into $K$ clusters.
#
# * number of clusters ($K$) - specified as a [model hyperparameter](MachineLearning_glossary_m_r.ipynb#model-hyperparameter) that controls the number of groups.
#
# * exhaustive and mutually exclusive groups - every data sample is assigned to exactly one cluster.
#
# * prototype method - represents the training data using a set of synthetic prototypes in feature space. For k-means clustering, $K$ prototypes are assigned and iteratively updated.
#
# * [unsupervised learning](MachineLearning_glossary_s_z.ipynb#unsupervised-learning) - training data are unlabeled and assigned cluster labels based on proximity to prototypes in feature space. The underlying assumption is that samples that are similar, represented by proximity in feature space, should belong to the same cluster.
#
# * feature weighting - k-means depends on Euclidean distance between training samples and prototypes. Distance is treated as an inverse measure of similarity. If features have significantly different magnitudes or ranges, features with larger values dominate the loss function and control the resulting clusters. Common approaches include [standardization](MachineLearning_glossary_s_z.ipynb#standardization) or [normalization](MachineLearning_glossary_m_r.ipynb#normalization) of features, while unequal feature weighting may also be applied. In this demonstration, features are normalized to a range from 0.0 to 1.0.
#
# * [heuristic algorithm](MachineLearning_glossary_g_l.ipynb#heuristic-algorithm) iterative solution - initial prototypes are assigned in the feature space, sample labels are updated by assigning each sample to the nearest prototype, and prototypes are recalculated as the centroid of their assigned samples. This process repeats until cluster assignments no longer change.
#
# Assumptions and limitations of k-means clustering,
#
# 1. spherical, [data convexity](MachineLearning_glossary_d_f.ipynb#data-convexity), isotropic clusters - minimizes distance between samples and their group prototype
#
# 2. equal variance for all features - requires reliable measures of distance in feature space
#
# 3. equal [prior](MachineLearning_glossary_m_r.ipynb#prior) probability for all clusters - naïve a priori clustering membership information (uniform distribution)
#
# Used in:
# - [k-Means Clustering Description and Demonstration](MachineLearning_clustering.ipynb#k-means-clustering-method)
#
# Also see:
# - [Prototype](MachineLearning_glossary_m_r.ipynb#prototype)
# - [Partitional Clustering](MachineLearning_glossary_m_r.ipynb#partitional-clustering)
#
# Contrast with:
# - [Density-based Clustering](MachineLearning_glossary_d_f.ipynb#density-based-clustering)
# - [Hierarchical Clustering](MachineLearning_glossary_g_l.ipynb#hierarchical-clustering)
#
#
# #### **k-Nearest Neighbours**
#
# Nonparametric predictive machine learning model based on a local weighting applied to the $k$ nearest training data, resulting in a method that is,
#
# * very simple, interpretable and flexible - the summary of the $k$ nearest training data can be easily explained
#
# * mapping - analogous to mapping in the [predictor feature space](MachineLearning_glossary_m_r.ipynb#predictor-feature-space)
#
# * adaptive - in regions with few training data the result is smoother than regions with denser training data available
#
# * instance-based, lazy learning method - the model training is postponed until [prediction](MachineLearning_glossary_m_r.ipynb#prediction) is required, no precalculation of the model. i.e., prediction requires access to the data.
#
# The k-nearest neighbours approach is conceptually related to [convolution](MachineLearning_glossary_a_c.ipynb#convolution) and kernel-based smoothing used in spatial interpolation. Both methods estimate a prediction at a location by applying weights to nearby information.
#
# In convolution, a weighting function (kernel) is shifted across a function to calculate a weighted [average](MachineLearning_glossary_a_c.ipynb#average),
#
# $$
# (f*g)(x)=\int_{-\infty}^{\infty} f(\Delta)g(x-\Delta)d\Delta
# $$
#
# where the weighting function controls the contribution of neighboring values.
#
# Similarly, k-nearest neighbours applies locally adaptive weighting by selecting the $k$ closest training samples in feature space and combining their values for prediction.
#
# * unlike standard convolution, where the weighting function and window size are predefined, k-nearest neighbours uses a data-driven neighborhood size determined by $k$.
#
# The hyperparameters include,
#
# * $k$ - number of nearest data to utilize for prediction
#
# * data weighting - for example uniform weighting with the local training data average, or inverse distance weighting
#
# Note, for the case of inverse distance weighting, the method is analogous to inverse distance weighted interpolation with a maximum number of local data constraint commonly applied for spatial interpolation.
#
# * inverse distance is available in GeostatsPy for spatial mapping.
#
# Too find the k-nearest data a distance metric is needed,
#
# * training data within the [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature) space are ranked by distance (closest to farthest)
#
# * a variety of distance metrics may be applied, including:
#
# 1. Euclidian distance
#
# $$
# d_i = \sqrt{\sum_{\alpha = 1}^{m} \left(x_{\alpha,i} - x_{\alpha,0}\right)^2}
# $$
#
# 2. [Minkowski Distance](MachineLearning_glossary_m_r.ipynb#minkowski-distance) - a general expression for distance with well-known Manhattan and Euclidean distances are special cases,
#
# $$
# d_{(i,i')} = \left( \sum_{j=1}^{m} \left( x_{(j,i)} - x_{(j,i')} \right)^p \right)^{\frac{1}{p}}
# $$
#
# * when $p=2$, this becomes the Euclidean distance
#
# * when $p=1$ it becomes the Manhattan distance
#
# Used in:
# - [k-Nearest Neighbours Description and Demonstration](MachineLearning_knearest_neighbours.ipynb#motivations-for-k-nearest-neighbours-regression)
#
# Also see:
# - [Lazy Learner](MachineLearning_glossary_g_l.ipynb#lazy-learning)
#
#
# #### **Kernel Trick**
#
# It is possible to incorporate a [basis expansion](MachineLearning_glossary_a_c.ipynb#basis-expansion) in our method without ever needing to transform the training data to this higher dimensional space,
#
# $$
# h(x)
# $$
#
# Instead, we only need the inner product over the [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s,
#
# $$
# h(x) \left( h(x') \right)^T = \langle h(x), h(x') \rangle
# $$
#
# instead of the actual values in the higher dimensional space, we just need the ‘similarity’ between all available training data in that transformed space! To emphasize this,
#
# * the radial [basis function](MachineLearning_glossary_a_c.ipynb#basis-function) (Gaussian) kernel with Taylor series expansion has inifite components, i.e., infinite dimensional space, but all we need is this similarity,
#
# $$
# K(\mathbf{x},\mathbf{x}') =
# \exp\left(-\frac{\|\mathbf{x}-\mathbf{x}'\|^2}{2\sigma^2}\right)
# $$
#
# An example application of the kernel trick for machine learning,
#
# * training our [support vector machine](MachineLearning_glossary_s_z.ipynb#support-vector-machine)s with only a similarity matrix between training data that will be projected to the higher dimensional space
#
# Used in:
# - [Support Vector Machine Description and Demonstration](MachineLearning_support_vector_machines.ipynb#support-vector-machine-model-with-linear-kernel)
#
# Also see:
# - [Support Vector](MachineLearning_glossary_s_z.ipynb#support-vector)
# - [Support Vector Machines](MachineLearning_glossary_s_z.ipynb#support-vector-machine)
# - [Margin](MachineLearning_glossary_m_r.ipynb#margin)
#
#
# #### **Key**
#
# A component of the [attention mechanism](MachineLearning_glossary_a_c.ipynb#attention-mechanism) that allows a model to dynamically focus on the most relevant information while reducing the influence of less relevant information.
#
# * A Key ($K$) is a descriptor used to determine whether stored information is relevant to a given [Query](MachineLearning_glossary_m_r.ipynb#query).
#
# The attention mechanism,
#
# * compares each Query with all Keys to calculate similarity scores, which are then used to derive [attention weights](MachineLearning_glossary_a_c.ipynb#attention-weights).
#
# Some additional comments,
#
# * each Key–[Value](MachineLearning_glossary_s_z.ipynb#value) pair represents a stored piece of information, where the Key describes the information and the Value contains the associated content.
#
# Used in:
# - [Definition and Demonstrations of Attention Mechanism](MachineLearning_attention.ipynb#attention-concepts)
#
# Also see:
# - [Query](MachineLearning_glossary_m_r.ipynb#query)
# - [Value](MachineLearning_glossary_s_z.ipynb#value)
#
#
# #### **Kolmogorov Probability Axioms**
#
# The three axioms proposed by [Andrey Kolmogorov](https://en.wikipedia.org/wiki/Andrey_Kolmogorov) that establish the rigorous mathematical foundation for probability theory.
#
# 1. Probability of an event is a non-negative number,
#
# $$
# P(A) \ge 0
# $$
#
# 2. Probability of the entire [sample](MachineLearning_glossary_s_z.ipynb#sample) space, all possible outcomes $\Omega$, is one (unity), also known as [probability closure](MachineLearning_glossary_m_r.ipynb#probability-closure),
#
# $$
# P(\Omega) = 1
# $$
#
# 3. Additivity of [mutually exclusive events](MachineLearning_glossary_m_r.ipynb#mutually-exclusive-events) for unions,
#
# $$
# P\left(\bigcup_{i=1}^{\infty} A_i\right) = \sum_{i=1}^{\infty} P(A_i)
# $$
#
# For example, the probability of two mutually exclusive events $A_1$ and $A_2$ is,
#
# $$
# P(A_1 \cup A_2) = P(A_1) + P(A_2)
# $$
#
# Used in:
# - [Kolmogorov's Probability Axioms](MachineLearning_probability.ipynb#probability-definition)
#
#
# #### **Kriging**
#
# Spatial [estimation](MachineLearning_glossary_d_f.ipynb#estimation) approach that relies on linear [weight](MachineLearning_glossary_s_z.ipynb#weight)s that account for spatial continuity, data closeness and redundancy. The kriging estimate is,
#
# $$
# z^*(\bf{u}) = \sum_{\alpha = 1}^{n} \lambda_{\alpha} \cdot z(\bf{u}_{\alpha}) + \left( 1.0 - \sum_{\alpha=1}^n \lambda_{\alpha} \right) \cdot m_z
# $$
#
# * the right term is the unbiasedness constraint, where one minus the sum of the weights is applied to the global mean.
#
# In the case where the [trend](MachineLearning_glossary_s_z.ipynb#trend), $t(\bf{u})$, is removed, we now have a residual, $y(\bf{u})$,
#
# $$
# y(\bf{u}) = z(\bf{u}) - t(\bf{u})
# $$
#
# the residual mean is zero so we can simplfy our kriging estimate as,
#
# $$
# y^*(\bf{u}) = \sum_{\alpha = 1}^{n} \lambda_{\alpha} \cdot y(\bf{u}_{\alpha})
# $$
#
# The simple kriging weights are calculated by solving a linear system of equations,
#
# $$
# \sum_{j=1}^n \lambda_j C(\bf{u}_i,\bf{u}_j) = C(\bf{u},\bf{u}_i), \quad i=1,\ldots,n
# $$
#
# that may be represented with matrix notation as,
#
# $$
# \begin{bmatrix}
# C(\bf{u}_1,\bf{u}_1) & C(\bf{u}_1,\bf{u}_2) & \dots & C(\bf{u}_1,\bf{u}_n) \\
# C(\bf{u}_2,\bf{u}_1) & C(\bf{u}_2,\bf{u}_2) & \dots & C(\bf{u}_2,\bf{u}_n) \\
# \vdots & \vdots & \ddots & \vdots \\
# C(\bf{u}_n,\bf{u}_1) & C(\bf{u}_n,\bf{u}_2) & \dots & C(\bf{u}_n,\bf{u}_n) \\
# \end{bmatrix} \cdot
# \begin{bmatrix}
# \lambda_1 \\ \lambda_2 \\ \vdots \\ \lambda_n \\
# \end{bmatrix} =
# \begin{bmatrix}
# C(\bf{u}_1,\bf{u}) \\ C(\bf{u}_2,\bf{u})  \\ \vdots \\ C(\bf{u}_n,\bf{u})  \\
# \end{bmatrix}
# $$
#
# This system may be derived by substituting the equation for kriging estimates into the equation for estimation variance, and then setting the partial derivative with respect to the weights to zero.
#
# * we are optimizing the weights to minimize the estimation variance
#
# this system integrates the,
#
# * spatial continuity - as quantified by the [variogram](MachineLearning_glossary_s_z.ipynb#variogram) (and [covariance function](MachineLearning_glossary_a_c.ipynb#covariance-function) to calculate the [covariance](MachineLearning_glossary_a_c.ipynb#covariance), $C$, values)
#
# * redundancy - the degree of spatial continuity between all of the available data with themselves, $C(\bf{u}_i,\bf{u}_j)$
#
# * closeness - the degree of spatial continuity between the available data and the estimation location, $C(\bf{u}_i,\bf{u})$
#
# Kriging provides a measure of estimation accuracy known as [kriging variance](MachineLearning_glossary_g_l.ipynb#kriging-variance) (a specific case of estimation variance).
#
# $$
# \sigma^{2}_{E}(\bf{u}) = C(0) - \sum^{n}_{\alpha = 1} \lambda_{\alpha} C(\bf{u}_0 - \bf{u}_{\alpha})
# $$
#
# Kriging estimates are best in that they minimize the above estimation variance.
#
# Properties of kriging estimates include,
#
# * Exact interpolator - kriging estimates with the data values at the data locations
#
# * [Kriging variance](MachineLearning_glossary_g_l.ipynb#kriging-variance) - a measure of uncertainty in a kriging estimate. Can be calculated before getting the [sample](MachineLearning_glossary_s_z.ipynb#sample) information, as the kriging estimation variance is not dependent on the values of the data nor the kriging estimate, i.e. the kriging estimator is homoscedastic.
#
# * Spatial context - kriging takes integrates spatial continuity, closeness and redundancy; therefore, kriging accounts for the configuration of the data and structural continuity of the feature being estimated.
#
# * Scale - kriging by default assumes the estimate and data are at the same point support, i.e., mathematically represented as points in space with zero volume. Kriging may be generalized to account for the support volume of the data and estimate,
#
# * [Multivariate](MachineLearning_glossary_m_r.ipynb#multivariate) - kriging may be generalized to account for multiple [secondary data](MachineLearning_glossary_s_z.ipynb#secondary-data) in the spatial estimate with the cokriging system. We will cover this later.
#
# * Smoothing effect - of kriging can be forecasted as the missing variance. The missing [variance](MachineLearning_glossary_s_z.ipynb#variance) over local estimates is the kriging variance.
#
#
# #### **Kriging Variance**
#
# A measure of accuracy and uncertainty for a [kriging](MachineLearning_glossary_g_l.ipynb#kriging) estimate, expressed as,
#
# $$
# \sigma^{2}_{z}(\bf{u}) = C(0) - \sum^{n}_{\alpha = 1} \lambda_{\alpha} C(\bf{u}_0 - \bf{u}_{\alpha})
# $$
#
# Kriging variance is a specific case of estimation variance,
#
# $$
# \sigma^{2}_{E}(\bf{u}) = E \left[ \left(z(\bf{u}) - z^{*}(\bf{u}) \right)^2 \right]
# $$
#
# Can be calculated before getting the [sample](MachineLearning_glossary_s_z.ipynb#sample) information,
#
# * the kriging estimation variance is not dependent on the values of the data nor the kriging estimate, i.e. the kriging estimator is homoscedastic.
#
#
# #### **Kriging-based Declustering**
#
# A [declustering](MachineLearning_glossary_d_f.ipynb#declustering) method to assign [weight](MachineLearning_glossary_s_z.ipynb#weight)s to spatial [sample](MachineLearning_glossary_s_z.ipynb#sample)s based on local sampling density using the spatial continuity model from a variogram model. The objective is to assign weights such that the weighted statistics are intended to be more representative of the [population](MachineLearning_glossary_m_r.ipynb#population).
#
# * samples in densely sampled areas receive less weight
#
# * samples in sparsely sampled areas receive more weight
#
# Kriging-based declustering proceeds as follows:
#
# 1. calculate and model the experimental variogram
#
# 2. apply kriging to calculate estimates over a high-resolution grid covering the [volume of interest](MachineLearning_glossary_s_z.ipynb#volume-of-interest)
#
# 3. accumulate the kriging weights assigned to each data [sample](MachineLearning_glossary_s_z.ipynb#sample) over the entire grid
#
# 4. assign declustering weights proportional to the accumulated kriging weights
#
# The kriging-based declustering weight for data sample $j$ is calculated as,
#
# $$
# w(\bf{u}_j) = n \cdot\frac{\sum_{iy=1}^{n_y}\sum_{ix=1}^{n_x}\lambda_{j,ix,iy}}{\sum_{j=1}^{n}\sum_{iy=1}^{n_y}\sum_{ix=1}^{n_x}\lambda_{j,ix,iy}}
# $$
#
# where $n$ is the number of data samples, $n_x$ and $n_y$ are the number of grid cells in the declustering grid, and $\lambda_{j,ix,iy}$ is the kriging weight assigned to data sample $j$ when estimating grid cell $ix,iy$.
#
# The resulting weights sum to the number of samples,
#
# $$
# \sum_{j=1}^{n} w(\bf{u}_j)=n
# $$
#
# which allows the weights to be directly applied in weighted statistics.
#
# Important considerations for kriging-based declustering,
#
# * like [polygonal declustering](MachineLearning_glossary_m_r.ipynb#polygonal-declustering), kriging-based declustering is sensitive to the boundaries of the area of interest; therefore, samples near the boundary may receive substantially different weights as the [area of interest](MachineLearning_glossary_a_c.ipynb#area-of-interest) is expanded or contracted.
#
# * kriging-based declustering integrates the spatial continuity model from the variogram. Therefore, the variogram model selection can significantly impact the resulting weights.
#
# * if there is a 100% relative nugget effect, there is no spatial continuity and all samples receive equal weight. In this case, the kriging weights contain no spatial information and the declustering calculation must be handled separately to avoid division by zero.
#
# * geometric anisotropy may significantly impact the weights because data aligned along preferred directions may be considered spatially closer or farther based on the [covariance function](MachineLearning_glossary_a_c.ipynb#covariance-function) model.
#
# Also see:
# - [Cell-based Declustering](MachineLearning_glossary_a_c.ipynb#cell-based-declustering)
# - [Polygonal Declustering](MachineLearning_glossary_m_r.ipynb#polygonal-declustering)
#
#
# #### **LASSO Regression**
#
# A regularized version of [linear regression](MachineLearning_glossary_g_l.ipynb#linear-regression). The acronym stands for,
#
# * Least Absolute Shrinkage and Selection Operator (LASSO),
#
# and it has the same [prediction](MachineLearning_glossary_m_r.ipynb#prediction) equation as linear regression,
#
# $$
# y=\sum_{\alpha=1}^{m}b_{\alpha}x_{\alpha}+b_0
# $$
#
# where the trainable [model parameter](MachineLearning_glossary_m_r.ipynb#model-parameter)s are $b_{\alpha}$, the feature [weight](MachineLearning_glossary_s_z.ipynb#weight)s, and $b_0$, the constant intercept term.
#
# The model parameters are estimated by minimizing a regularized least squares [loss function](MachineLearning_glossary_g_l.ipynb#loss-function) that combines the residual sum of squares (RSS) with an L1 shrinkage penalty,
#
# $$
# \sum_{i=1}^{n}\left(y_i-\left(\sum_{\alpha=1}^{m}b_{\alpha}x_{\alpha,i}+b_0\right)\right)^2+\lambda\sum_{\alpha=1}^{m}|b_{\alpha}|
# $$
#
# where $y_i$ is the observed [response feature](MachineLearning_glossary_m_r.ipynb#response-feature) value and $\sum_{\alpha=1}^{m}b_{\alpha}x_{\alpha,i}+b_0$ is the model prediction for training sample $i$.
#
# LASSO [regression](MachineLearning_glossary_m_r.ipynb#regression) introduces the hyperparameter $\lambda$, which controls the strength of the L1 regularization penalty,
#
# $$
# \lambda\sum_{\alpha=1}^{m}|b_{\alpha}|
# $$
#
# where,
#
# * larger values of $\lambda$ increase the penalty on large slope coefficients
#
# * the intercept term $b_0$ is not penalized because it represents the response mean rather than predictor influence
#
# LASSO regression integrates two competing goals during model training,
#
# * minimize [prediction error](MachineLearning_glossary_m_r.ipynb#prediction-error) with respect to the training data
#
# * minimize the magnitude of the slope parameters toward zero
#
# The hyperparameter $\lambda$ controls the [model bias–variance trade-off](MachineLearning_glossary_m_r.ipynb#model-biasvariance-trade-off),
#
# * as $\lambda\rightarrow0$, the solution approaches ordinary linear regression with no additional regularization bias, but potentially higher model variance
#
# * as $\lambda$ increases, [model variance](MachineLearning_glossary_m_r.ipynb#model-variance) decreases and [model bias](MachineLearning_glossary_m_r.ipynb#model-bias) increases as the model becomes less flexible
#
# * as $\lambda\rightarrow\infty$, the slope parameters $b_1,\ldots,b_m$ approach zero and predictions approach the response feature mean
#
# Due to the L1 regularization penalty, LASSO regression performs feature selection,
#
# * as $\lambda$ increases, some model parameters are forced exactly to zero, effectively removing the corresponding [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s from the model
#
# Compared with [ridge regression](MachineLearning_glossary_m_r.ipynb#ridge-regression),
#
# * Ridge regression uses L2 regularization and shrinks coefficients toward zero, but generally retains all predictor features
#
# * LASSO regression uses L1 regularization and can shrink some coefficients exactly to zero, performing automatic feature selection
#
# The assumptions of LASSO regression include,
#
# * Error-free predictors - predictor features are treated as known values, not random variables
#
# * Linearity - the expected response is a linear combination of predictor features
#
# * Constant variance - the variance of response error is constant over predictor feature values (homoscedasticity)
#
# * [independence](MachineLearning_glossary_g_l.ipynb#independence) of error - errors in the response are uncorrelated with each other
#
# * Redundant predictors - highly correlated predictor features may reduce the stability of feature selection
#
# Used in:
# - [LASSO Regression Description and Demonstration](MachineLearning_LASSO_regression.ipynb#lasso-regression-method)
#
# Also see:
# - [Linear Regression](MachineLearning_glossary_g_l.ipynb#linear-regression)
# - [Ridge Regression](MachineLearning_glossary_m_r.ipynb#ridge-regression)
# - [Polynomial Regression](MachineLearning_glossary_m_r.ipynb#polynomial-regression)
# - [Model Parameter](MachineLearning_glossary_m_r.ipynb#model-parameter)
#
#
# #### **Latent Feature**
#
# A feature that is not directly observed in the original data but is learned or inferred by a model to represent underlying patterns, structure, or relationships.
#
# * the feature exists in a [latent space](MachineLearning_glossary_g_l.ipynb#latent-space)
#
# Latent features are typically combinations or transformations of the original [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s and often provide a more compact or meaningful representation of the data.
#
# Used in:
# - [Latent Feature Encoding with Autoencoder Description and Demonstration](MachineLearning_autoencoder.ipynb#autoencoder-architecture)
#
# Also see:
# - [Latent Space](MachineLearning_glossary_g_l.ipynb#latent-space)
# - [Feature Projection](MachineLearning_glossary_d_f.ipynb#feature-projection)
# - [Principal Component Analysis](MachineLearning_glossary_m_r.ipynb#principal-component-analysis)
# - [Autoencoder](MachineLearning_glossary_a_c.ipynb#autoencoder)
# - [Dimensionality Reduction](MachineLearning_glossary_d_f.ipynb#dimensionality-reduction)
#
#
# #### **Latent Space**
#
# A lower-dimensional representation of data in which the coordinates correspond to [Latent Feature](MachineLearning_glossary_g_l.ipynb#latent-feature) that capture the underlying structure or patterns in the original data.
#
# Latent features are not directly observed but are learned or inferred from the data during model training.
#
# Data represented in a latent space often preserves important relationships while reducing dimensionality, enabling tasks such as visualization, clustering, compression, and generation.
#
# Used in:
# - [Latent Feature Encoding with Autoencoder Description and Demonstration](MachineLearning_autoencoder.ipynb#autoencoder-architecture)
#
# Also see:
# - [Latent Feature](MachineLearning_glossary_g_l.ipynb#latent-feature)
# - [Feature Projection](MachineLearning_glossary_d_f.ipynb#feature-projection)
# - [Principal Component Analysis](MachineLearning_glossary_m_r.ipynb#principal-component-analysis)
# - [Autoencoder](MachineLearning_glossary_a_c.ipynb#autoencoder)
# - [Dimensionality Reduction](MachineLearning_glossary_d_f.ipynb#dimensionality-reduction)
#
#
# #### **Lazy Learning**
#
# A machine learning approach where the training data are retained and generalization is performed when [prediction](MachineLearning_glossary_m_r.ipynb#prediction) queries are made.
#
# * after selecting [model hyperparameter](MachineLearning_glossary_m_r.ipynb#model-hyperparameter)s, the model retains the original training data and uses them directly during prediction
#
# * the computational effort is concentrated during the prediction phase, while training is typically fast
#
# Examples include,
#
# * [k-Nearest Neighbours](MachineLearning_glossary_g_l.ipynb#k-nearest-neighbours)
#
# * locally weighted regression
#
# * case-based reasoning
#
# Used in:
# - [k-Nearest Neighbours Regression Description and Demonstration](MachineLearning_knearest_neighbours.ipynb#motivations-for-k-nearest-neighbours-regression)
#
# Also see:
# - [Model Hyperparameter Tuning](MachineLearning_glossary_m_r.ipynb#model-hyperparameter-tuning)
# - [Prediction](MachineLearning_glossary_m_r.ipynb#prediction)
#
# Contrast with:
# - [Eager Learning](MachineLearning_glossary_d_f.ipynb#eager-learning)
#
#
# #### **Leave-One-Out Cross Validation**
#
# A [K-fold Cross Validation](MachineLearning_glossary_g_l.ipynb#k-fold-cross-validation)-based [cross validation](MachineLearning_glossary_a_c.ipynb#cross-validation) method with one sample withheld for testing in each fold, such that the number of folds equals the number of samples, $K=n$.
#
# Leave-one-out cross validation uses nearly all available data for training in each fold but may have high computational cost and high variance in the estimated predictive performance.
#
# Contrast with:
# - [K-fold Cross Validation](MachineLearning_glossary_g_l.ipynb#k-fold-cross-validation)
#
# Also see:
# - [cross validation](MachineLearning_glossary_a_c.ipynb#cross-validation)
#
#
# #### **Likelihood Function**
#
# In [Bayes' Theorem](MachineLearning_probability.ipynb#bayes-theorem), the likelihood function describes the compatibility of new data with possible states or inferred model parameters. It quantifies how likely the observed data are for different model assumptions and is combined with the [prior](MachineLearning_glossary_m_r.ipynb#prior) probability to calculate the [posterior](MachineLearning_glossary_m_r.ipynb#posterior) probability,
#
# $$
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
# $$
#
# where:
#
# - $P(A)$ is the [prior](MachineLearning_glossary_m_r.ipynb#prior) probability representing uncertainty before observing new information,
#
# - $P(B|A)$ is the [likelihood function](MachineLearning_glossary_g_l.ipynb#likelihood-function) describing the compatibility of observations $B$ with state or parameter $A$,
#
# - $P(B)$ is the [evidence](MachineLearning_glossary_d_f.ipynb#evidence) term used to normalize the posterior probability,
#
# - $P(A|B)$ is the [posterior](MachineLearning_glossary_m_r.ipynb#posterior) probability representing updated uncertainty after incorporating observations.
#
# Used in:
# - [Bayesian Probability Definition and Demonstration](MachineLearning_probability.ipynb#bayesian-probability)
# - [Bayesian Probability Example Problems](MachineLearning_probability.ipynb#bayesian-probability-example-problems)
# - [Bayesian Linear Regression Description and Demonstration](MachineLearning_Bayesian_linear_regression.ipynb#bayesian-linear-regression-with-the-metropolis-hastings-sampler)
# - [Naive Bayes Description and Demonstration](MachineLearning_naive_Bayes.ipynb#naive-bayes-approach)
#
# Also see:
# - [Bayes' Theorem](MachineLearning_glossary_a_c.ipynb#bayes-theorem).
# - [Prior](MachineLearning_glossary_m_r.ipynb#prior)
# - [Posterior](MachineLearning_glossary_m_r.ipynb#posterior)
# - [Evidence](MachineLearning_glossary_d_f.ipynb#evidence)
#
#
# #### **Linear Regression**
#
# Simple, linear parametric [prediction](MachineLearning_glossary_m_r.ipynb#prediction) model based on a linear [weight](MachineLearning_glossary_s_z.ipynb#weight)ed combination of the [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s with a constant term,
#
# $$
# y=\sum_{\alpha=1}^{m}b_{\alpha}x_{\alpha}+b_0
# $$
#
# where the trainable [model parameter](MachineLearning_glossary_m_r.ipynb#model-parameter)s are $b_{\alpha}$, the feature weights, and $b_0$, the constant intercept term.
#
# The analytical solution for the model parameters, $b_1,\ldots,b_m,b_0$, is available by minimizing the L2 [norm](MachineLearning_glossary_m_r.ipynb#norm) [loss function](MachineLearning_glossary_g_l.ipynb#loss-function). This is known as least squares because the residual errors are squared and summed over all training data,
#
# $$
# RSS=\sum_{i=1}^{n}\left(y_i-\left(\sum_{\alpha=1}^{m}b_{\alpha}x_{\alpha,i}+b_0\right)\right)^2
# $$
#
# where $y_i$ is the observed [response feature](MachineLearning_glossary_m_r.ipynb#response-feature) value and $\sum_{\alpha=1}^{m}b_{\alpha}x_{\alpha,i}+b_0$ is the model prediction for training [sample](MachineLearning_glossary_s_z.ipynb#sample) $i$.
#
# The assumptions of linear [regression](MachineLearning_glossary_m_r.ipynb#regression) include,
#
# * Error-free predictors - predictor features are treated as known values, not [random variable](MachineLearning_glossary_m_r.ipynb#random-variable)s
#
# * Linearity - the expected response is a linear combination of predictor features
#
# * Constant [variance](MachineLearning_glossary_s_z.ipynb#variance) - the variance of the response error is constant over predictor feature values (homoscedasticity)
#
# * I[independence](MachineLearning_glossary_g_l.ipynb#independence) of error - errors in the response are uncorrelated with each other
#
# * No multicollinearity - predictor features are not linearly redundant with each other
#
# Used in:
# - [Linear Regression Description and Demonstration](MachineLearning_linear_regression.ipynb#linear-regression-method)
#
# Also see:
# - [Ridge Regression](MachineLearning_glossary_m_r.ipynb#ridge-regression)
# - [Polynomial Regression](MachineLearning_glossary_m_r.ipynb#polynomial-regression)
# - [Model Parameter](MachineLearning_glossary_m_r.ipynb#model-parameter)
#
#
# #### **Local Accuracy**
#
# Accuracy of a spatial estimate at individual locations, typically assessed by minimizing the local estimation uncertainty or estimation error.
#
# For kriging, local accuracy is achieved by minimizing the estimation variance,
#
# $$
# \sigma^2_E(\mathbf{u}) = \text{Var}\left[ Z^*(\mathbf{u}) - Z(\mathbf{u}) \right]
# $$
#
# where $Z^*(\mathbf{u})$ is the estimated value and $Z(\mathbf{u})$ is the unknown true value.
#
# Some general observations about local accuracy,
#
# * [estimation](MachineLearning_glossary_d_f.ipynb#estimation) methods prioritize local accuracy by honoring nearby data and minimizing estimation variance.
#
# * locally accurate estimates are often smooth because they represent the best estimate at each location, but they generally do not reproduce the spatial variability of the modeled feature.
#
# * estimates optimized for local accuracy may not reproduce [global measures](MachineLearning_glossary_g_l.ipynb#global-measure), such as the [histogram](MachineLearning_glossary_g_l.ipynb#histogram), variogram, or [correlation coefficient](MachineLearning_glossary_a_c.ipynb#correlation-coefficient).
#
# Used in:
# - [Model Checks for Global Accuracy Description and Demonstration](MachineLearning_model_checking.ipynb#spatial-modeling)
#
# Contrast with:
# - [Global Accuracy](MachineLearning_glossary_g_l.ipynb#global-accuracy)
#
#
# #### **Local Measure**
#
# A statistical measure that evaluates model performance at individual locations or over a local neighborhood.
#
# Local measures are used to assess [local accuracy](MachineLearning_glossary_g_l.ipynb#local-accuracy).
#
# * local measures focus on location-specific agreement between estimates and observations or local uncertainty.
#
# * local measures do not assess reproduction of [global measures](MachineLearning_glossary_g_l.ipynb#global-measure), such as the entire [histogram](MachineLearning_glossary_g_l.ipynb#histogram), variogram, or [correlation coefficient](MachineLearning_glossary_a_c.ipynb#correlation-coefficient).
#
# Used in:
# - [Model Checks for Global Accuracy Description and Demonstration](MachineLearning_model_checking.ipynb#spatial-modeling)
#
# Contrast with:
# - [Global Measure](MachineLearning_glossary_g_l.ipynb#global-measure)
#
#
# #### **Logistic Regression**
#
# A supervised machine learning method that predicts the probability of membership in a [categorical feature](MachineLearning_glossary_a_c.ipynb#categorical-feature) by applying a logistic function to a linear combination of the [predictor feature](MachineLearning_glossary_m_r.ipynb#predictor-feature)s.
#
# * unlike [linear regression](MachineLearning_glossary_g_l.ipynb#linear-regression), logistic regression predicts probabilities between 0 and 1, which may then be converted to class assignments.
#
# Model parameters are estimated by minimizing the [cross-entropy loss](MachineLearning_glossary_a_c.ipynb#cross-entropy-loss) during [model parameter training](MachineLearning_glossary_m_r.ipynb#model-parameter-training).
#
# Applications include,
#
# * binary classification
#
# * multiclass classification (with suitable extensions)
#
# Used in:
# TBA
#
# Also see:
# - [Classification](MachineLearning_glossary_a_c.ipynb#classification)
# - [Categorical Feature](MachineLearning_glossary_a_c.ipynb#categorical-feature)
# - [Linear Regression](MachineLearning_glossary_g_l.ipynb#linear-regression)
# - [Cross-Entropy Loss](MachineLearning_glossary_a_c.ipynb#cross-entropy-loss)
# - [Model Parameter Training](MachineLearning_glossary_m_r.ipynb#model-parameter-training)
#
#
# #### **Loss Function**
#
# Mathematical function that quantifies and summarizes the loss associated with the [prediction error](MachineLearning_glossary_m_r.ipynb#prediction-error)s over the training data and provides the objective minimized during model training.
#
# For [supervised learning](MachineLearning_glossary_s_z.ipynb#supervised-learning), the general form is,
#
# $$
# L(Y,\hat{Y})
# $$
#
# where $Y$ is the observed [response feature](MachineLearning_glossary_m_r.ipynb#response-feature) values and $\hat{Y}$ are the corresponding model [prediction](MachineLearning_glossary_m_r.ipynb#prediction)s.
#
# A loss function,
#
# * quantifies the agreement between model predictions and the observed response feature values
#
# * provides a single objective for [model parameter](MachineLearning_glossary_m_r.ipynb#model-parameter) optimization
#
# * is minimized during model training
#
# The total loss over the training data is commonly calculated by aggregating the individual sample losses,
#
# $$
# L=\sum_{i=1}^{n}L(y_i,\hat{y}_i)
# $$
#
# or by averaging,
#
# $$
# L=\frac{1}{n}\sum_{i=1}^{n}L(y_i,\hat{y}_i)
# $$
#
# depending on the learning algorithm.
#
# Common [regression](MachineLearning_glossary_m_r.ipynb#regression) loss functions include,
#
# * Mean Squared Error (MSE) - squares prediction errors, emphasizing larger errors
#
# * Mean Absolute Error (MAE) - uses absolute prediction errors and is more robust to outliers
#
# * Huber Loss - combines the robustness of MAE with the smooth optimization properties of MSE
#
# Common [classification](MachineLearning_glossary_a_c.ipynb#classification) loss functions include,
#
# * Cross-Entropy Loss (Log Loss) - compares predicted class probabilities with the observed categories
#
# * Hinge Loss - used by [support vector machine](MachineLearning_glossary_s_z.ipynb#support-vector-machine)s to maximize the classification margin
#
# Additional comments,
#
# * the choice of loss function influences the model parameters learned during training
#
# * the loss function used for training does not have to be the same metric used to evaluate model performance
#
# * regularization terms are often added to the loss function to reduce [model complexity](MachineLearning_glossary_m_r.ipynb#model-complexity) and improve generalization
#
# Examples include,
#
# * [linear regression](MachineLearning_glossary_g_l.ipynb#linear-regression) - [Residual Sum of Squares](MachineLearning_glossary_m_r.ipynb#residual-sum-of-squares) (RSS)
#
# * [ridge regression](MachineLearning_glossary_m_r.ipynb#ridge-regression) - residual sum of squares (RSS) plus an L2 regularization penalty
#
# * [LASSO regression](MachineLearning_glossary_g_l.ipynb#lasso-regression)  - residual sum of squares (RSS) plus an L1 regularization penalty
#
# * [neural network](MachineLearning_glossary_m_r.ipynb#neural-network) - [Mean Squared Error](MachineLearning_glossary_m_r.ipynb#mean-square-error) (MSE) for regression or cross-entropy for classification
#
# * [generative adversarial network](MachineLearning_glossary_g_l.ipynb#generative-adversarial-network) - [Cross-Entropy Loss](MachineLearning_glossary_a_c.ipynb#cross-entropy-loss)
#
# Used in:
# - [Loss Function for Linear Regression Description and Demonstration](MachineLearning_linear_regression.ipynb#analytical-solution)
# - [Loss Function for Ridge Regression Description and Demonstration](MachineLearning_ridge_regression.ipynb#ridge-regression-method)
# - [Loss Function for LASSO Regression Description and Demonstration](MachineLearning_LASSO_regression.ipynb#lasso-regression-method)
# - [Loss Function for Decision Tree Description and Demonstration](MachineLearning_decision_tree.ipynb#tree-loss-functions)
# - [Loss Function for Random Forest Description and Demonstration](MachineLearning_ensemble_trees.ipynb#training-and-tuning-bagging-models)
#
# Also see:
# - [Prediction Error](MachineLearning_glossary_m_r.ipynb#prediction-error)
# - [Mean Squared Error](MachineLearning_glossary_m_r.ipynb#mean-square-error)
# - [Mean Absolute Error](MachineLearning_glossary_m_r.ipynb#mean-absolute-error)
# - [Residual Sum of Squares](MachineLearning_glossary_m_r.ipynb#residual-sum-of-squares)
# - [Cross-Entropy Loss](MachineLearning_glossary_a_c.ipynb#cross-entropy-loss)
# - [Gradient-based Optimization](MachineLearning_glossary_g_l.ipynb#gradient-based-optimization)
# - [Model Parameter](MachineLearning_glossary_m_r.ipynb#model-parameter)

# %% [markdown]
# #### Comments
#
# This was a basic introduction to geostatistics. If you would like more on these fundamental concepts I recommend the Introduction, Modeling Principles and Modeling Prerequisites chapters from my text book, [Geostatistical Reservoir Modeling](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446){cite}`pyrcz2014'.
#
# I hope this is helpful,
#
# *Michael*
#
# #### The Author:
#
# Michael Pyrcz, Professor, The University of Texas at Austin
# *Novel Data Analytics, Geostatistics and Machine Learning Subsurface Solutions*
#
# With over 17 years of experience in subsurface consulting, research and development, Michael has returned to academia driven by his passion for teaching and enthusiasm for enhancing engineers' and geoscientists' impact in subsurface resource development.
#
# For more about Michael check out these links:
#
# [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Geostatistics Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [Applied Geostats in Python e-book](https://geostatsguy.github.io/GeostatsPyDemos_Book/intro.html) | [Applied Machine Learning in Python e-book](https://geostatsguy.github.io/MachineLearningDemos_Book/) | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
#
# #### Want to Work Together?
#
# I hope this content is helpful to those that want to learn more about subsurface modeling, data analytics and machine learning. Students and working professionals are welcome to participate.
#
# * Want to invite me to visit your company for training, mentoring, project review, workflow design and / or consulting? I'd be happy to drop by and work with you!
#
# * Interested in partnering, supporting my graduate student research or my Subsurface Data Analytics and Machine Learning consortium (co-PIs including Profs. Foster, Torres-Verdin and van Oort)? My research combines data analytics, stochastic modeling and machine learning theory with practice to develop novel methods and workflows to add value. We are solving challenging subsurface problems!
#
# * I can be reached at mpyrcz@austin.utexas.edu.
#
# I'm always happy to discuss,
#
# *Michael*
#
# Michael Pyrcz, Ph.D., P.Eng. Professor, Cockrell School of Engineering and The Jackson School of Geosciences, The University of Texas at Austin
#
# More Resources Available at: [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Geostatistics Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [Applied Geostats in Python e-book](https://geostatsguy.github.io/GeostatsPyDemos_Book/intro.html) | [Applied Machine Learning in Python e-book](https://geostatsguy.github.io/MachineLearningDemos_Book/) | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
